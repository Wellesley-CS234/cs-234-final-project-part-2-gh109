# %% [markdown]
# Filtering articles 2023-2024 so gets qids of ones that actually ahve been viewed

# %%
import requests
import mwclient
import json, os
import csv
import pandas as pd
from io import StringIO
from datetime import datetime, timedelta

# %%
daily_df = pd.read_csv("physics_pageviews.csv")
unique_qids = daily_df["qid"].unique()
unique_qids.size

unique_qids
# Out:
# 4730

# %%
# This file was created iteratatively with Gemini and Google Colab over a series of multiple prompts.
# Here are the prompts
"""
Prompt 1: given the QID of a Wikipedia article, I want a python script that uses a python 
library wrapper to query Wikidata. My interest is to find out whether the page belongs to 
a human entity and if so, what is their gender or sex, their profession, and their date of 
birth. Can you write such a script. 

Prompt 2: This was great and it worked really well. I want now to focus on non-human entities. 
What kind of information I can get from the Wikidata page about such entities? To give you more 
context, I have access to Wikipedia pageviews data and I want to be able to say: pages about 
movies have more traffic than pages about sport events, or pages about science concepts are 
more popular than pages about historical events. Can you help extract meaningful data from 
the Wikidata page about non-humans? Create a new function about that. Imagine that we first 
check if a page is human or not, than if not human, call this function about the properties 
of such a page. 

Prompt 3: this works, are there any other attributes that can be added in addition to instance_of, 
country, and start date? 

Prompt 4: is there a dynamic way to get information? for example, is there a scraper of Wikidata? 
That is, if I go to this page: https://www.wikidata.org/wiki/Q83285, my scraper gives me a JSON 
of all attribute:values in the page. How is the HTML page created? Maybe data is passed as a 
JSON and we can use it directly. 

Prompt 5: now that I have the Property IDs for an entity in Wikidata, how do I get the corresponding
values of what they mean and what their values are for a given QID.

Prompt 6: okay, you got the names of the property IDs in the entry for the QID I provided you, 
but now I want to see their values, for example, what is the value for the P17 (country) for this 
QID, and so on. You'll need a second function to do this, at the end, I would like pairs like: 
"country": "Albania", "population": 113,249, and so on.
"""


import requests
import json, os

WIKIDATA_API_ENDPOINT = "https://www.wikidata.org/w/api.php"

def fetch_complete_entity_data(qid):
    """
    Fetches all available structured data for a single Wikidata entity (QID)
    using the official Wikibase API action=wbgetentities.

    Args:
        qid (str): The Wikidata Item ID (e.g., 'Q83285' for Durres).

    Returns:
        dict: The complete raw JSON data for the entity, or an error dictionary.
    """

    # Parameters for the MediaWiki API, using the 'wbgetentities' action
    params = {
        'action': 'wbgetentities',
        'ids': qid,
        'format': 'json',
        # Request all relevant data: claims (properties), labels, descriptions, sitelinks (Wikipedia links)
        'props': 'claims|labels|descriptions|sitelinks|aliases',
    }

    # Add a User-Agent header as recommended by Wikidata API policies
    # https://www.wikidata.org/wiki/Wikidata:Contact_the_development_team#User-Agent
    headers = {
        'User-Agent': 'Colab-Wikidata-Example/1.0 (https://colab.research.google.com; colab-user@example.com)'
    }

    try:
        response = requests.get(WIKIDATA_API_ENDPOINT, 
                                params=params, 
                                headers=headers, 
                                timeout=10)
        response.raise_for_status()  # Raises an HTTPError for bad responses (4xx or 5xx)

        data = response.json()

        # Check for potential errors in the API response structure
        if 'error' in data:
            return {"error": f"API Error for {qid}: {data['error']['info']}"}

        # The core data is nested under ['entities'][qid]
        entity_data = data.get('entities', {}).get(qid)

        if entity_data:
            return entity_data
        else:
            return {"error": f"Entity {qid} not found or no data returned."}

    except requests.exceptions.RequestException as e:
        return {"error": f"Network or API request error: {e}"}
    except json.JSONDecodeError:
        return {"error": "Failed to decode JSON response."}

def _chunk_list(lst, n):
    """
    Yields successive n-sized chunks from lst.
    """
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def fetch_labels_for_qids(qids: list[str], lang='en'):
    """
    Fetches labels for a list of Wikidata QIDs or Property IDs.
    Handles API limits by chunking the requests.

    Args:
        qids (list[str]): A list of Wikidata Item IDs or Property IDs (e.g., ['Q515', 'P31']).
        lang (str): The language code for the labels (default is 'en').

    Returns:
        dict: A dictionary mapping QID to its label, or an error dictionary.
    """
    if not qids:
        return {}

    # Wikidata API limit for 'ids' parameter is typically 50
    MAX_IDS_PER_REQUEST = 50
    all_labels_map = {}

    # Chunk the QID list to respect the API limit
    for qid_chunk in _chunk_list(qids, MAX_IDS_PER_REQUEST):
        params = {
            'action': 'wbgetentities',
            'ids': '|'.join(qid_chunk), # Join QIDs with '|' for multiple requests
            'format': 'json',
            'props': 'labels',
            'languages': lang,
        }

        headers = {
            'User-Agent': 'Colab-Wikidata-Example/1.0 (https://colab.research.google.com; colab-user@example.com)'
        }

        try:
            response = requests.get(WIKIDATA_API_ENDPOINT, params=params, headers=headers, timeout=10)
            response.raise_for_status() # Raises an HTTPError for bad responses (4xx or 5xx)

            data = response.json()

            if 'error' in data:
                # If an error occurs in one chunk, return it immediately or log and continue
                return {"error": f"API Error fetching labels for chunk {qid_chunk}: {data['error']['info']}"}

            for qid_key, entity_info in data.get('entities', {}).items():
                label = entity_info.get('labels', {}).get(lang, {}).get('value')
                if label:
                    all_labels_map[qid_key] = label

        except requests.exceptions.RequestException as e:
            return {"error": f"Network or API request error for chunk {qid_chunk}: {e}"}
        except json.JSONDecodeError:
            return {"error": "Failed to decode JSON response for a label chunk."}

    return all_labels_map

def extract_labeled_claim_values(claims: dict, property_labels: dict) -> dict:
    """
    Extracts the main value for each claim, resolves QID values to labels,
    and returns a dictionary of 'property_label': 'value' pairs.

    Args:
        claims (dict): The 'claims' section of a Wikidata entity's data.
        property_labels (dict): A dictionary mapping Property IDs (P-numbers) to their labels.

    Returns:
        dict: A dictionary where keys are property labels and values are their extracted/resolved values.
    """
    labeled_values = {}
    qids_to_resolve = set() # Collect all QIDs that need labels

    # First pass: Extract raw values and collect QIDs
    extracted_raw_values = {}
    for prop_id, statements in claims.items():
        prop_label = property_labels.get(prop_id, prop_id) # Use ID if label not found
        
        # We often care about the primary value of the first statement for simplicity
        if statements:
            main_snak = statements[0].get('mainsnak')
            if not main_snak or 'datavalue' not in main_snak: # Skip if no main value
                continue

            data_value = main_snak['datavalue']
            value_type = data_value.get('type')

            if value_type == 'wikibase-entityid':
                qid_value = data_value['value']['id']
                extracted_raw_values[prop_label] = qid_value # Store QID for later resolution
                qids_to_resolve.add(qid_value)
            elif value_type == 'string' or value_type == 'external-id':
                extracted_raw_values[prop_label] = data_value['value']
            elif value_type == 'quantity':
                # Format quantity with unit if available
                amount = data_value['value']['amount']
                unit = data_value['value'].get('unit', '').replace('http://www.wikidata.org/entity/', '')
                if unit and unit != '1': # '1' is the URI for dimensionless unit
                    # Attempt to add unit to QID list for resolution
                    if unit.startswith('Q'):
                        qids_to_resolve.add(unit)
                        extracted_raw_values[prop_label] = (amount, unit) # Store as tuple for later unit resolution
                    else:
                        extracted_raw_values[prop_label] = f"{amount} {unit}" # Simple string for non-QID units
                else:
                    extracted_raw_values[prop_label] = amount
            elif value_type == 'time':
                # Simple representation for time
                extracted_raw_values[prop_label] = data_value['value']['time']
            elif value_type == 'globecoordinate':
                latitude = data_value['value']['latitude']
                longitude = data_value['value']['longitude']
                extracted_raw_values[prop_label] = f"Lat: {latitude}, Lon: {longitude}"
            elif value_type == 'monolingualtext':
                extracted_raw_values[prop_label] = data_value['value']['text']
            # Add more types as needed
            else:
                # For unhandled types or complex structures, just show the raw datavalue
                extracted_raw_values[prop_label] = f"[Unhandled Type: {value_type}]"

    # Second pass: Resolve QID values and units to labels
    if qids_to_resolve:
        resolved_value_labels = fetch_labels_for_qids(list(qids_to_resolve))
        if "error" in resolved_value_labels:
            print(f"Warning: Could not resolve some value labels: {resolved_value_labels['error']}")
            # Proceed with raw QIDs if resolution fails
            pass

        for prop_label, value in extracted_raw_values.items():
            if isinstance(value, str) and value.startswith('Q'):
                labeled_values[prop_label] = resolved_value_labels.get(value, value) # Use raw QID if label not found
            elif isinstance(value, tuple) and len(value) == 2 and value[1].startswith('Q'): # Handle quantity with QID unit
                amount, unit_qid = value
                unit_label = resolved_value_labels.get(unit_qid, unit_qid)
                labeled_values[prop_label] = f"{amount} {unit_label}"
            else:
                labeled_values[prop_label] = value
    else:
        labeled_values = extracted_raw_values # No QIDs to resolve

    return labeled_values

def test_one(QID):
    """
    Demonstrates fetching the complete JSON data for a given QID string
    and then resolving labels for properties and their values.
    """
    # The entity for the Durres city
    qid_example = QID
    print(f"--- Fetching ALL structured data for {qid_example} \n")

    entity_data = fetch_complete_entity_data(qid_example)

    if "error" in entity_data:
        print(f"Error: {entity_data['error']}")
        return

    # Display main entity's label and description
    print(f"--- Main Entity Details ({qid_example}) ---")
    entity_label = entity_data.get('labels', {}).get('en', {}).get('value', 'No label found')
    entity_description = entity_data.get('descriptions', {}).get('en', {}).get('value', 'No description found')
    print(f"Label: {entity_label}")
    print(f"Description: {entity_description}\n")

    print("--- Full Raw JSON Structure (Truncated for readability) ---")

    # We will print the Claims section specifically to show the attribute:value pairs
    claims = entity_data.get('claims', {}) # This is the full claims dict
    print(f"\nTotal Properties (Claims) Found: {len(claims)}\n")

    # Get labels for the property IDs themselves
    property_ids = list(claims.keys())
    property_labels = fetch_labels_for_qids(property_ids)
    if "error" in property_labels:
        #print(f"Error fetching property labels: {property_labels['error']}")
        property_labels = {pid: pid for pid in property_ids} # Fallback to IDs if labels fail
    else:
        #print("Property IDs found for this entity:")
        # Print property IDs with their labels
        labeled_properties_overview = {pid: property_labels.get(pid, 'Label Not Found') for pid in property_ids}
        #print(json.dumps(labeled_properties_overview, indent=2))

    # Now, extract and label the claim values
    print("\n--- Extracted Labeled Claim Values ---")
    labeled_claim_values = extract_labeled_claim_values(claims, property_labels)
    print(json.dumps(labeled_claim_values, indent=2, ensure_ascii=False))

    print("\n--- Details for 'P31' (instance of) ---")

    if 'P31' in claims:
        # P31 is 'instance of', and it will contain an array of statements
        p31_statements = claims['P31']

        # Iterate over the values found for P31
        extracted_value_qids = []
        for statement in p31_statements:
            # The value is usually nested deep in the datavalue section
            main_snak = statement['mainsnak']
            if main_snak['datavalue']['type'] == 'wikibase-entityid':
                value_qid = main_snak['datavalue']['value']['id']
                extracted_value_qids.append(value_qid)

        # Get the label for the P31 property itself
        p31_label = property_labels.get('P31', 'Label Not Found for P31')
        print(f"Property P31 label: '{p31_label}'")

        # Get the labels for the extracted QID values
        value_labels = fetch_labels_for_qids(extracted_value_qids)

        if "error" in value_labels:
            print(f"Error fetching value labels: {value_labels['error']}")
        else:
            print(f"Raw QID values for 'instance of' (P31): {extracted_value_qids}")
            labeled_values = [value_labels.get(qid, 'Label Not Found') for qid in extracted_value_qids]
            print(f"Labeled values for 'instance of' (P31): {labeled_values}")
    else:
        print("P31 property not found in claims.")

    print("\n------------------------------------------------------------")
    print("This raw data contains every single piece of structured information available for the entity.")


def process_qids_to_jsonl(qid_list, output_filename="entity_data.jsonl"):
    """
    Processes a list of QIDs, fetches structured data, labels it, and stores
    the results (or errors) into a JSONL file.
    
    Args:
        qid_list (list): A list of QID strings (e.g., ['Q534', 'Q142', 'Q999']).
        output_filename (str): The name of the JSONL file to write results to.
    """
    print(f"Starting processing for {len(qid_list)} QIDs.")
    print(f"Results will be written to '{output_filename}'.")
    
    successful_count = 0
    failed_count = 0

    with open(output_filename, 'w', encoding='utf-8') as f:
        for qid in qid_list:
            print(f"Processing {qid}...")
            
            # Initialize the base record structure
            record = {"QID": qid, "status": "failed", "error_message": None}
            
            try:
                # 1. Fetch raw entity data (using your existing function)
                entity_data = fetch_complete_entity_data(qid)

                if "error" in entity_data:
                    # Handle API/Not Found error directly
                    record["error_message"] = entity_data['error']
                    failed_count += 1
                else:
                    # 2. Extract basic details
                    entity_label = entity_data.get('labels', {}).get('en', {}).get('value', 'No label found')
                    entity_description = entity_data.get('descriptions', {}).get('en', {}).get('value', 'No description found')
                    claims = entity_data.get('claims', {})
                    
                    # 3. Get labels for the properties themselves (using your existing function)
                    property_ids = list(claims.keys())
                    property_labels = fetch_labels_for_qids(property_ids)

                    if "error" in property_labels:
                        # Fallback for label fetching error
                        property_labels = {pid: pid for pid in property_ids} 
                        print(f"  Warning: Failed to fetch property labels for {qid}. Using IDs.")
                    
                    # 4. Extract and label all claim values (using your existing function)
                    labeled_claim_values = extract_labeled_claim_values(claims, property_labels)

                    # 5. Structure the final dictionary for successful outcome
                    record.update({
                        "status": "success",
                        "label": entity_label,
                        "description": entity_description,
                        "attributes": labeled_claim_values
                    })
                    record.pop("error_message") # Remove error key on success
                    successful_count += 1
            
            except Exception as e:
                # Catch any unexpected execution errors
                record["error_message"] = f"Unexpected execution error: {type(e).__name__} - {e}"
                failed_count += 1

            # 6. Write the final record (whether success or failure) to the JSONL file
            json_line = json.dumps(record, ensure_ascii=False)
            f.write(json_line + '\n')
    
    print("\n--- Processing Complete ---")
    print(f"Total Processed: {len(qid_list)}")
    print(f"Successful Records: {successful_count}")
    print(f"Failed Records: {failed_count}")
    print("---------------------------\n")

if __name__ == "__main__":
    #test_one("Q83285") # Article about Durres
    #test_one("Q7186")  # Article about Marie Kurie

    # I'm putting the list here, but you'll have a file with a list of QIDs here.
    qid_list_to_process = [
        "Q83285",    
        "Q7186",     
        "Q777",     
        "Q999",     
    ]
    
    output_file = "entity_results.jsonl"

    # Run the main function
    process_qids_to_jsonl(qid_list_to_process, output_file)
# Out:
# Starting processing for 4 QIDs.
# Results will be written to 'entity_results.jsonl'.
# Processing Q83285...
# Processing Q7186...
# Processing Q777...
# Processing Q999...
#
# --- Processing Complete ---
# Total Processed: 4
# Successful Records: 4
# Failed Records: 0
# ---------------------------

# %%
process_qids_to_jsonl(unique_qids, output_filename="entity_data.jsonl")
# Out:
# Starting processing for 4730 QIDs.
# Results will be written to 'entity_data.jsonl'.
# Processing Q166530...
# Processing Q208138...
# Processing Q33198...
# Processing Q2027476...
# Processing Q177045...
# Processing Q2164598...
# Processing Q15605...
# Processing Q209675...
# Processing Q6733...
# Processing Q1052...
# Processing Q39552...
# Processing Q8739...
# Processing Q2225...
# Processing Q36496...
# Processing Q128709...
# Processing Q6718...
# Processing Q16134223...
# Processing Q3198...
# Processing Q15873...
# Processing Q607699...
# Processing Q381913...
# Processing Q172858...
# Processing Q12438...
# Processing Q25342...
# Processing Q284602...
# Processing Q83481...
# Processing Q181741...
# Processing Q39369...
# Processing Q180600...
# Processing Q217365...
# Processing Q11406...
# Processing Q49285...
# Processing Q525...
# Processing Q7544...
# Processing Q40609...
# Processing Q11656...
# Processing Q18343...
# Processing Q11455...
# Processing Q11412...
# Processing Q11651...
# Processing Q11652...
# Processing Q27221300...
# Processing Q220277...
# Processing Q45003...
# Processing Q41591...
# Processing Q7085...
# Processing Q450317...
# Processing Q40605...
# Processing Q25269...
# Processing Q122894...
# Processing Q5962...
# Processing Q83152...
# Processing Q935...
# Processing Q1102...
# Processing Q9095...
# Processing Q33539...
# Processing Q11448...
# Processing Q219563...
# Warning: Could not resolve some value labels: API Error fetching labels for chunk ['Q5083', 'Q432637', 'Q113624884', 'Q8884844', 'Q62078547', 'Q4917', 'Q386819', 'Q32644899', 'Q98970039', 'Q1860', 'Q2944483', 'Q541394', 'Q8975569', 'Q550397', 'Q5275906', 'Q19310187', 'E349', 'Q21932100', 'Q7896565', 'Q19047539', 'Q99194765', 'Q30']: Could not find an entity with the ID "E349".
# Processing Q1116609...
# Processing Q50053...
# Processing Q238125...
# Processing Q11429...
# Processing Q107...
# Processing Q185918...
# Processing Q868...
# Processing Q619...
# Processing Q101038...
# Processing Q21264604...
# Processing Q43533...
# Processing Q83197...
# Processing Q322177...
# Processing Q207342...
# Processing Q410...
# Processing Q47270...
# Processing Q6500960...
# Processing Q6422690...
# Processing Q11430...
# Processing Q170282...
# Processing Q207488...
# Processing Q8081...
# Processing Q12969754...
# Processing Q556...
# Processing Q7604...
# Processing Q132537...
# Processing Q6722...
# Processing Q38867...
# Processing Q64122...
# Processing Q25670...
# Processing Q468999...
# Processing Q114998390...
# Processing Q37501...
# Processing Q174102...
# Processing Q5871...
# Processing Q1341528...
# Processing Q183759...
# Processing Q338...
# Processing Q131313...
# Processing Q80877...
# Processing Q178828...
# Processing Q17455...
# Processing Q641442...
# Processing Q25272...
# Processing Q43116...
# Processing Q48171...
# Processing Q127995...
# Processing Q17714...
# Processing Q41273...
# Processing Q182333...
# Processing Q208589...
# Processing Q124003...
# Processing Q35758...
# Processing Q187536...
# Processing Q12725...
# Processing Q65402698...
# Processing Q173582...
# Processing Q11388...
# Processing Q10693...
# Processing Q173412...
# Processing Q54389...
# Processing Q18373...
# Processing Q323...
# Processing Q622063...
# Processing Q719349...
# Processing Q11402...
# Processing Q307...
# Processing Q32566...
# Processing Q9036...
# Processing Q413...
# Processing Q44432...
# Processing Q7186...
# Processing Q2294...
# Processing Q201424...
# Processing Q181328...
# Processing Q2513...
# Processing Q1098...
# Processing Q201513...
# Processing Q11471...
# Processing Q72313...
# Processing Q83333...
# Processing Q232184...
# Processing Q717216...
# Processing Q859...
# Processing Q134465...
# Processing Q1290...
# Processing Q1515261...
# Processing Q463581...
# Processing Q181465...
# Processing Q134447...
# Processing Q486882...
# Processing Q221392...
# Processing Q39246...
# Processing Q83327...
# Processing Q83213...
# Processing Q43514...
# Processing Q18338...
# Processing Q649143...
# Processing Q163415...
# Processing Q193803...
# Processing Q11423...
# Processing Q11452...
# Processing Q11461...
# Processing Q136407...
# Processing Q33297...
# Processing Q523...
# Warning: Could not resolve some value labels: API Error fetching labels for chunk ['Q1', 'Q634', 'E440', 'Q5623575', 'Q10251', 'Q2041543', 'P881', 'Q333', 'Q6999', 'Q595871', 'Q6259679', 'Q30318006', 'Q5460604', 'Q7037', 'Q589', 'Q17444909', 'Q26540', 'Q14914807']: Could not find an entity with the ID "E440".
# Processing Q40590...
# Processing Q83373...
# Processing Q179289...
# Processing Q175974...
# Processing Q504027...
# Processing Q33741...
# Processing Q155890...
# Processing Q625107...
# Processing Q103983...
# Processing Q188524...
# Processing Q9121...
# Processing Q161238...
# Processing Q182154...
# Processing Q211786...
# Processing Q272621...
# Processing Q11379...
# Processing Q1128589...
# Processing Q6158...
# Processing Q11628...
# Processing Q25250...
# Processing Q849392...
# Processing Q13082...
# Processing Q42944...
# Processing Q232405...
# Processing Q3196...
# Processing Q900097...
# Processing Q12739...
# Processing Q11456...
# Processing Q139931...
# Processing Q4262...
# Processing Q146123...
# Processing Q76299...
# Processing Q131566...
# Processing Q9128...
# Processing Q54505...
# Processing Q16491...
# Processing Q12457...
# Processing Q160047...
# Processing Q244743...
# Processing Q130964...
# Processing Q830791...
# Processing Q309331...
# Processing Q7950...
# Processing Q6203...
# Processing Q20882...
# Processing Q40392...
# Processing Q201721...
# Processing Q1315...
# Processing Q11426...
# Processing Q178192...
# Processing Q166314...
# Processing Q34286...
# Processing Q83219...
# Processing Q402...
# Processing Q8070...
# Warning: Could not resolve some value labels: API Error fetching labels for chunk ['Q3421345', 'Q6418532', 'Q22828680', 'Q7944', 'Q1069', 'Q8068', 'Q5460604', 'E115', 'Q8065']: Could not find an entity with the ID "E115".
# Processing Q188533...
# Processing Q267298...
# Processing Q727000...
# Processing Q1344605...
# Processing Q40904...
# Processing Q46221...
# Processing Q102296...
# Processing Q41509...
# Processing Q379848...
# Processing Q178036...
# Processing Q44395...
# Processing Q204570...
# Processing Q1...
# Processing Q57384...
# Processing Q910355...
# Processing Q161254...
# Processing Q315730...
# Processing Q531...
# Processing Q1307...
# Processing Q44235...
# Processing Q193320...
# Processing Q916906...
# Processing Q169917...
# Processing Q834826...
# Processing Q15221814...
# Processing Q7474...
# Processing Q192962...
# Processing Q333...
# Processing Q1784385...
# Processing Q2494783...
# Processing Q44559...
# Warning: Could not resolve some value labels: API Error fetching labels for chunk ['P1046', 'Q634', 'Q18611609', 'Q1863380', 'Q7217174', 'Q6173448', 'Q6443358', 'Q17444909', 'E128', 'Q3809431', 'Q686876']: Could not find an entity with the ID "E128".
# Processing Q5604...
# Processing Q199691...
# Processing Q10745598...
# Processing Q472374...
# Processing Q1129469...
# Processing Q133139...
# Processing Q131133...
# Processing Q1792138...
# Processing Q589...
# Processing Q76436...
# Processing Q11466...
# Processing Q38433...
# Processing Q186212...
# Processing Q9251458...
# Processing Q937...
# Processing Q13915...
# Processing Q41155...
# Processing Q8753...
# Processing Q189325...
# Processing Q48103...
# Processing Q5329...
# Processing Q380770...
# Processing Q192457...
# Processing Q2126...
# Processing Q283...
# Processing Q1968311...
# Processing Q25236...
# Processing Q488020...
# Processing Q641227...
# Processing Q177013...
# Processing Q10251...
# Processing Q81809...
# Processing Q101600...
# Processing Q178932...
# Processing Q133327...
# Processing Q4437154...
# Processing Q4202...
# Processing Q41364...
# Processing Q11408...
# Processing Q223323...
# Processing Q51501...
# Processing Q234181...
# Processing Q215675...
# Processing Q44746...
# Processing Q130825...
# Processing Q127050...
# Processing Q323320...
# Processing Q305208...
# Processing Q18335...
# Processing Q79925...
# Processing Q160669...
# Processing Q124131...
# Processing Q1328068...
# Processing Q34777...
# Processing Q11469...
# Processing Q560...
# Processing Q7099...
# Processing Q3937...
# Processing Q217785...
# Processing Q3327819...
# Processing Q232207...
# Processing Q897...
# Processing Q46276...
# Processing Q11579...
# Processing Q81182...
# Processing Q487756...
# Processing Q646419...
# Processing Q10261...
# Processing Q47083...
# Processing Q11523...
# Processing Q5095243...
# Processing Q5339...
# Processing Q191785...
# Processing Q2348...
# Processing Q17394326...
# Processing Q42915945...
# Processing Q161064...
# Processing Q36488...
# Processing Q8963...
# Processing Q11391...
# Processing Q11421...
# Processing Q165618...
# Processing Q11570...
# Processing Q310903...
# Processing Q190463...
# Processing Q8750...
# Processing Q1331626...
# Processing Q190056...
# Processing Q2091584...
# Processing Q175751...
# Processing Q268421...
# Processing Q663611...
# Processing Q334631...
# Processing Q179380...
# Processing Q11582...
# Processing Q11475...
# Processing Q333268...
# Processing Q11432...
# Processing Q56189...
# Processing Q11473...
# Processing Q826582...
# Processing Q169890...
# Processing Q217255...
# Processing Q181780...
# Processing Q23392...
# Processing Q18359...
# Processing Q23384...
# Processing Q131468...
# Processing Q12705...
# Processing Q738628...
# Processing Q46344...
# Processing Q16985269...
# Processing Q23809...
# Processing Q8092...
# Processing Q3482342...
# Processing Q9021...
# Processing Q11369...
# Processing Q186161...
# Processing Q2374463...
# Processing Q76250...
# Processing Q11547...
# Processing Q164399...
# Processing Q81041...
# Processing Q1511415...
# Processing Q217200...
# Processing Q464704...
# Processing Q1111...
# Processing Q4440864...
# Processing Q162...
# Processing Q285048...
# Processing Q79785...
# Processing Q7366241...
# Processing Q212986...
# Processing Q3294789...
# Processing Q210659...
# Processing Q500699...
# Processing Q497396...
# Processing Q47480...
# Processing Q133220...
# Processing Q8094...
# Processing Q17995793...
# Processing Q2118982...
# Processing Q25276...
# Processing Q123371...
# Processing Q235451...
# Processing Q483261...
# Processing Q527628...
# Processing Q37463...
# Processing Q2742884...
# Processing Q992476...
# Processing Q12802...
# Processing Q48983...
# Processing Q182453...
# Processing Q45621...
# Processing Q11382...
# Processing Q664150...
# Processing Q622424...
# Processing Q3574371...
# Processing Q49833...
# Processing Q240581...
# Processing Q11418...
# Processing Q118398...
# Processing Q1974806...
# Processing Q38104...
# Processing Q4327971...
# Processing Q102145...
# Processing Q2111...
# Processing Q180253...
# Processing Q1569889...
# Processing Q110360...
# Processing Q934700...
# Processing Q757554...
# Processing Q2742300...
# Processing Q656857...
# Processing Q380171...
# Processing Q79833...
# Processing Q11415...
# Processing Q8068...
# Processing Q3359049...
# Processing Q970542...
# Processing Q25428...
# Processing Q220620...
# Processing Q429050...
# Processing Q725699...
# Processing Q120688...
# Processing Q325611...
# Processing Q18362...
# Processing Q35197...
# Processing Q7311409...
# Processing Q325470...
# Processing Q35820...
# Processing Q673166...
# Processing Q179036...
# Processing Q26336...
# Processing Q64470499...
# Processing Q44207...
# Processing Q243969...
# Processing Q824561...
# Processing Q428887...
# Processing Q117812...
# Processing Q2222575...
# Processing Q92894...
# Processing Q898375...
# Processing Q591022...
# Processing Q180381...
# Processing Q13156052...
# Processing Q82586...
# Processing Q464794...
# Processing Q43101...
# Processing Q1051979...
# Processing Q15978265...
# Processing Q41995...
# Processing Q131255...
# Processing Q215913...
# Processing Q8104...
# Processing Q607538...
# Processing Q180809...
# Processing Q11774759...
# Processing Q490600...
# Processing Q18334...
# Processing Q189155...
# Processing Q20725194...
# Processing Q497332...
# Processing Q4847219...
# Processing Q336233...
# Processing Q3944788...
# Processing Q179916...
# Processing Q1059081...
# Processing Q378201...
# Processing Q177897...
# Processing Q334269...
# Processing Q234943...
# Processing Q855630...
# Processing Q333094...
# Processing Q29564079...
# Processing Q4131656...
# Processing Q41585...
# Processing Q62542...
# Processing Q830787...
# Processing Q179745...
# Processing Q215772...
# Processing Q188734...
# Processing Q170464...
# Processing Q1516738...
# Processing Q29539...
# Processing Q2493651...
# Processing Q190688...
# Processing Q1779048...
# Processing Q178841...
# Processing Q3234202...
# Processing Q2076321...
# Processing Q7572183...
# Processing Q37547...
# Processing Q130768...
# Processing Q3984056...
# Processing Q3517825...
# Processing Q810911...
# Processing Q483400...
# Processing Q381490...
# Processing Q103246...
# Processing Q22247...
# Processing Q1576675...
# Processing Q2637631...
# Processing Q9438778...
# Processing Q43027...
# Processing Q6856398...
# Processing Q49295...
# Processing Q194306...
# Processing Q193709...
# Processing Q83301...
# Processing Q123524...
# Processing Q917571...
# Processing Q1591311...
# Processing Q1396898...
# Processing Q4744748...
# Processing Q1031651...
# Processing Q944...
# Processing Q221337...
# Processing Q2307936...
# Processing Q5160249...
# Processing Q583313...
# Processing Q2214042...
# Processing Q133900...
# Processing Q23580887...
# Processing Q13418630...
# Processing Q103510...
# Processing Q244040...
# Processing Q245739...
# Processing Q723510...
# Processing Q190035...
# Processing Q2086630...
# Processing Q902174...
# Processing Q123300...
# Processing Q212397...
# Processing Q36303...
# Processing Q169973...
# Processing Q40015...
# Processing Q51497...
# Processing Q123280...
# Processing Q737571...
# Processing Q221033...
# Processing Q768575...
# Processing Q26761...
# Processing Q321095...
# Processing Q1401317...
# Processing Q169577...
# Processing Q284681...
# Processing Q1425110...
# Processing Q219982...
# Processing Q9123...
# Processing Q120665636...
# Processing Q7198547...
# Processing Q80884...
# Processing Q172948...
# Processing Q28869675...
# Processing Q57475...
# Processing Q4360...
# Processing Q2909689...
# Processing Q181892...
# Processing Q58978...
# Processing Q997...
# Processing Q174920...
# Processing Q61761...
# Processing Q153238...
# Processing Q1366475...
# Processing Q386272...
# Processing Q57066...
# Processing Q153717...
# Processing Q310765...
# Processing Q1141329...
# Processing Q46079...
# Processing Q3229...
# Processing Q372001...
# Processing Q852317...
# Processing Q1344449...
# Processing Q1349434...
# Processing Q216938...
# Processing Q184499...
# Processing Q714439...
# Processing Q2371844...
# Processing Q172118...
# Processing Q57065...
# Processing Q1389242...
# Processing Q1550453...
# Processing Q322456...
# Processing Q1386318...
# Processing Q3023711...
# Processing Q1219068...
# Processing Q204469...
# Processing Q105789...
# Processing Q15079318...
# Processing Q65989...
# Processing Q306786...
# Processing Q1079490...
# Processing Q14946885...
# Processing Q2656967...
# Processing Q1192374...
# Processing Q1751751...
# Processing Q788017...
# Processing Q1369818...
# Processing Q1321523...
# Processing Q473252...
# Processing Q5563970...
# Processing Q706086...
# Processing Q695856...
# Processing Q931545...
# Processing Q127944...
# Processing Q155790...
# Processing Q3052232...
# Processing Q337641...
# Processing Q2281897...
# Processing Q714440...
# Processing Q77729...
# Processing Q1291942...
# Processing Q47285...
# Processing Q4102679...
# Processing Q2362761...
# Processing Q59105814...
# Processing Q649120...
# Processing Q1569514...
# Processing Q6207234...
# Processing Q1365270...
# Processing Q7597638...
# Processing Q123022...
# Processing Q208470...
# Processing Q81197...
# Processing Q178344...
# Processing Q183679...
# Processing Q605089...
# Processing Q1356799...
# Processing Q4562662...
# Processing Q585062...
# Processing Q705994...
# Processing Q108293603...
# Processing Q3151...
# Processing Q234881...
# Processing Q1374577...
# Processing Q1003183...
# Processing Q124313...
# Processing Q65455964...
# Processing Q1529908...
# Processing Q28189...
# Processing Q1328219...
# Processing Q1503574...
# Processing Q1896787...
# Processing Q1943137...
# Processing Q33447...
# Processing Q103854...
# Processing Q577432...
# Processing Q273711...
# Processing Q234909...
# Processing Q441154...
# Processing Q6586653...
# Processing Q6236928...
# Processing Q119830...
# Processing Q949...
# Processing Q847588...
# Processing Q46525465...
# Processing Q133673...
# Processing Q2743592...
# Processing Q185969...
# Processing Q79852...
# Processing Q263961...
# Processing Q11397...
# Processing Q828224...
# Processing Q1188682...
# Processing Q2821842...
# Processing Q188589...
# Processing Q93768470...
# Processing Q1194544...
# Processing Q178380...
# Processing Q911916...
# Processing Q3446091...
# Processing Q82580...
# Processing Q186310...
# Processing Q179856...
# Processing Q108779...
# Processing Q370906...
# Processing Q193788...
# Processing Q211569...
# Processing Q284885...
# Processing Q1357469...
# Processing Q11476...
# Processing Q6643508...
# Processing Q56218...
# Processing Q186713...
# Processing Q179388...
# Processing Q6497624...
# Processing Q12185286...
# Processing Q364988...
# Processing Q47574...
# Processing Q214336...
# Processing Q935310...
# Processing Q255371...
# Processing Q324669...
# Processing Q321046...
# Processing Q48973...
# Processing Q138076...
# Processing Q6434802...
# Processing Q223662...
# Processing Q1988917...
# Processing Q37172...
# Processing Q573846...
# Processing Q467258...
# Processing Q212082...
# Processing Q34929...
# Processing Q961734...
# Processing Q836595...
# Processing Q575625...
# Processing Q8772...
# Processing Q143631...
# Processing Q940334...
# Processing Q844736...
# Processing Q104934...
# Processing Q72277...
# Processing Q6915...
# Processing Q1371132...
# Processing Q2661322...
# Processing Q310798...
# Processing Q656181...
# Processing Q117801...
# Processing Q1040643...
# Processing Q531716...
# Processing Q161853...
# Processing Q230883...
# Processing Q155794...
# Processing Q3238843...
# Processing Q527601...
# Processing Q161424...
# Processing Q4854529...
# Processing Q131214...
# Processing Q5997...
# Processing Q130011...
# Processing Q215007...
# Processing Q61231...
# Processing Q179282...
# Processing Q201048...
# Processing Q110779037...
# Processing Q505654...
# Processing Q13409892...
# Processing Q733109...
# Processing Q1133705...
# Processing Q13471665...
# Processing Q131089...
# Processing Q20702...
# Processing Q776050...
# Processing Q104541...
# Processing Q169470...
# Processing Q1192186...
# Processing Q1778729...
# Processing Q7068214...
# Processing Q899137...
# Processing Q48378...
# Processing Q726815...
# Processing Q159190...
# Processing Q12623...
# Processing Q1404167...
# Processing Q1148691...
# Processing Q2522514...
# Processing Q41257...
# Processing Q155640...
# Processing Q81454...
# Processing Q193907...
# Processing Q739536...
# Processing Q628096...
# Processing Q677864...
# Processing Q1155939...
# Processing Q1127660...
# Processing Q408891...
# Processing Q2611270...
# Processing Q152466...
# Processing Q42213...
# Processing Q1060321...
# Processing Q647349...
# Processing Q3062538...
# Processing Q4920115...
# Processing Q908880...
# Processing Q5121676...
# Processing Q217219...
# Processing Q57073...
# Processing Q170835...
# Processing Q623761...
# Processing Q596353...
# Processing Q192127...
# Processing Q911473...
# Processing Q660488...
# Processing Q37147...
# Processing Q388525...
# Processing Q1647152...
# Processing Q2382024...
# Processing Q161635...
# Processing Q103517...
# Processing Q190095...
# Processing Q15318...
# Processing Q223818...
# Processing Q1022922...
# Processing Q1753580...
# Processing Q72755...
# Processing Q7356995...
# Processing Q6763...
# Processing Q13400897...
# Processing Q468438...
# Processing Q208476...
# Processing Q860589...
# Processing Q2094637...
# Processing Q191788...
# Processing Q163343...
# Processing Q17105011...
# Processing Q691858...
# Processing Q1132713...
# Processing Q842433...
# Processing Q220184...
# Processing Q308762...
# Processing Q170731...
# Processing Q55451...
# Processing Q206621...
# Processing Q106667...
# Processing Q592031...
# Processing Q759767...
# Processing Q4698744...
# Processing Q2945326...
# Processing Q834200...
# Processing Q25424022...
# Processing Q382037...
# Processing Q483538...
# Processing Q461382...
# Processing Q184996...
# Processing Q828402...
# Processing Q317382...
# Processing Q1065997...
# Processing Q131800...
# Processing Q4893914...
# Processing Q484092...
# Processing Q41284...
# Processing Q210546...
# Processing Q207456...
# Processing Q47103...
# Processing Q10656...
# Processing Q883757...
# Processing Q1401749...
# Processing Q51504...
# Processing Q849699...
# Processing Q187672...
# Processing Q578555...
# Processing Q107414...
# Processing Q232086...
# Processing Q61931...
# Processing Q836828...
# Processing Q622975...
# Processing Q193442...
# Processing Q261585...
# Processing Q102742...
# Processing Q809676...
# Processing Q752034...
# Processing Q110330...
# Processing Q578970...
# Processing Q190132...
# Processing Q6583695...
# Processing Q7556707...
# Processing Q618153...
# Processing Q13632...
# Processing Q1087688...
# Processing Q5044103...
# Processing Q474044...
# Processing Q11248330...
# Processing Q925640...
# Processing Q16221926...
# Processing Q54237...
# Processing Q1287337...
# Processing Q126818...
# Processing Q842189...
# Processing Q724183...
# Processing Q614981...
# Processing Q742969...
# Processing Q1418211...
# Processing Q815820...
# Processing Q899222...
# Processing Q184207...
# Processing Q21014316...
# Processing Q505913...
# Processing Q371884...
# Processing Q682585...
# Processing Q46830...
# Processing Q201666...
# Processing Q314267...
# Processing Q190241...
# Processing Q65069068...
# Processing Q11210...
# Processing Q186610...
# Processing Q165044...
# Processing Q165896...
# Processing Q59151...
# Processing Q1577504...
# Processing Q44528...
# Processing Q83094...
# Processing Q10281355...
# Processing Q428895...
# Processing Q830521...
# Processing Q11376...
# Processing Q192510...
# Processing Q196538...
# Processing Q131594...
# Processing Q181369...
# Processing Q732673...
# Processing Q466416...
# Processing Q844102...
# Processing Q275393...
# Processing Q891653...
# Processing Q1517374...
# Processing Q1066997...
# Processing Q40164...
# Processing Q207340...
# Processing Q599404...
# Processing Q4420061...
# Processing Q190070...
# Processing Q36253...
# Processing Q732722...
# Processing Q60429...
# Processing Q2295762...
# Processing Q1155653...
# Processing Q2074906...
# Processing Q136980...
# Processing Q1080745...
# Processing Q232976...
# Processing Q2667302...
# Processing Q102205...
# Processing Q212903...
# Processing Q959005...
# Processing Q677855...
# Processing Q180892...
# Processing Q3036449...
# Processing Q6458...
# Processing Q192316...
# Processing Q221076...
# Processing Q214634...
# Processing Q80222...
# Processing Q83375...
# Processing Q183173...
# Processing Q10564323...
# Processing Q483948...
# Processing Q20873229...
# Processing Q25261...
# Processing Q7556087...
# Processing Q275411...
# Processing Q185357...
# Processing Q194376...
# Processing Q4235042...
# Processing Q170373...
# Processing Q46587...
# Processing Q2699749...
# Processing Q115857894...
# Processing Q827688...
# Processing Q1139177...
# Processing Q901057...
# Processing Q17106019...
# Processing Q188479...
# Processing Q111092...
# Processing Q15149343...
# Processing Q7454819...
# Processing Q473227...
# Processing Q4299309...
# Processing Q190760...
# Processing Q179043...
# Processing Q202631...
# Processing Q628595...
# Processing Q188603...
# Processing Q2613048...
# Processing Q552456...
# Processing Q190120...
# Processing Q1548694...
# Processing Q622938...
# Processing Q163354...
# Processing Q856634...
# Processing Q209233...
# Processing Q131687...
# Processing Q192735...
# Processing Q523919...
# Processing Q783766...
# Processing Q381287...
# Processing Q1135332...
# Processing Q1823370...
# Processing Q133235...
# Processing Q338886...
# Processing Q1193128...
# Processing Q37640...
# Processing Q321017...
# Processing Q162219...
# Processing Q736716...
# Processing Q834199...
# Processing Q208702...
# Processing Q471726...
# Processing Q193540...
# Processing Q76323...
# Processing Q43522...
# Processing Q1095492...
# Processing Q426656...
# Processing Q333921...
# Processing Q3271631...
# Processing Q162564...
# Processing Q474043...
# Processing Q267131...
# Processing Q1076349...
# Processing Q29474217...
# Processing Q206310...
# Processing Q203989...
# Processing Q53859...
# Processing Q477921...
# Processing Q221037...
# Processing Q1195325...
# Processing Q2630196...
# Processing Q604907...
# Processing Q192116...
# Processing Q654136...
# Processing Q5602021...
# Processing Q44481...
# Processing Q4027242...
# Processing Q215405...
# Processing Q235544...
# Processing Q620602...
# Processing Q217113...
# Processing Q845238...
# Processing Q53860...
# Processing Q172137...
# Processing Q106410...
# Processing Q43518...
# Processing Q14672...
# Processing Q173356...
# Processing Q132560...
# Processing Q208474...
# Processing Q44363...
# Processing Q11435...
# Processing Q215571...
# Processing Q898493...
# Processing Q120919994...
# Processing Q35158...
# Processing Q188715...
# Processing Q173227...
# Processing Q25303639...
# Processing Q1073486...
# Processing Q2638786...
# Processing Q332774...
# Processing Q384952...
# Processing Q1778961...
# Processing Q1195471...
# Processing Q1366187...
# Processing Q104225...
# Processing Q2945123...
# Processing Q189452...
# Processing Q826939...
# Processing Q211922...
# Processing Q228736...
# Processing Q140028...
# Processing Q2297564...
# Processing Q1645498...
# Processing Q213659...
# Processing Q60815...
# Processing Q193846...
# Processing Q1133068...
# Processing Q3711325...
# Processing Q192275...
# Processing Q205702...
# Processing Q170749...
# Processing Q809690...
# Processing Q30006...
# Processing Q3734365...
# Processing Q422141...
# Processing Q103585...
# Processing Q177625...
# Processing Q191807...
# Processing Q12453...
# Processing Q101667...
# Processing Q148109...
# Processing Q862169...
# Processing Q206175...
# Processing Q1439884...
# Processing Q10359898...
# Processing Q11468...
# Processing Q2803875...
# Processing Q838974...
# Processing Q15982668...
# Processing Q6501125...
# Processing Q79602...
# Processing Q3396184...
# Processing Q1685498...
# Processing Q640404...
# Processing Q190837...
# Processing Q909221...
# Processing Q208391...
# Processing Q898323...
# Processing Q213488...
# Processing Q11465...
# Processing Q181404...
# Processing Q727023...
# Processing Q131502...
# Processing Q638328...
# Processing Q1422588...
# Processing Q208376...
# Processing Q338613...
# Processing Q1775058...
# Processing Q2036633...
# Processing Q214753...
# Processing Q122701...
# Processing Q865788...
# Processing Q6478447...
# Processing Q865447...
# Processing Q211702...
# Processing Q1783782...
# Processing Q533498...
# Processing Q634340...
# Processing Q178733...
# Processing Q139771...
# Processing Q2920177...
# Processing Q6472...
# Processing Q746338...
# Processing Q172881...
# Processing Q122508...
# Processing Q692197...
# Processing Q227467...
# Processing Q351087...
# Processing Q7572639...
# Processing Q189000...
# Processing Q1471710...
# Processing Q185744...
# Processing Q93996...
# Processing Q190426...
# Processing Q884593...
# Processing Q568496...
# Processing Q193793...
# Processing Q845981...
# Processing Q9492...
# Processing Q84296...
# Processing Q3299...
# Processing Q182925...
# Processing Q129890...
# Processing Q18349003...
# Processing Q1642768...
# Processing Q693177...
# Processing Q51368...
# Processing Q7796236...
# Processing Q4213...
# Processing Q507667...
# Processing Q1048664...
# Processing Q165294...
# Processing Q43302...
# Processing Q3501532...
# Processing Q8814...
# Processing Q876377...
# Processing Q646...
# Processing Q3197317...
# Processing Q902336...
# Processing Q428788...
# Processing Q14620...
# Processing Q582000...
# Processing Q3141097...
# Processing Q80956...
# Processing Q2607394...
# Processing Q4119786...
# Processing Q8421...
# Processing Q653711...
# Processing Q131733...
# Processing Q1028292...
# Processing Q1345036...
# Processing Q2895606...
# Processing Q219708...
# Processing Q215928...
# Processing Q1048589...
# Processing Q3695436...
# Processing Q41688...
# Processing Q785107...
# Processing Q1414106...
# Processing Q584905...
# Processing Q565544...
# Processing Q175973...
# Processing Q1110547...
# Processing Q470468...
# Processing Q96148782...
# Processing Q1407668...
# Processing Q1807778...
# Processing Q265653...
# Processing Q203243...
# Processing Q211736...
# Processing Q467736...
# Processing Q191134...
# Processing Q944604...
# Processing Q179057...
# Processing Q190453...
# Processing Q15710733...
# Processing Q208147...
# Processing Q579338...
# Processing Q214781...
# Processing Q721085...
# Processing Q185252...
# Processing Q1302...
# Processing Q1351267...
# Processing Q1133376...
# Processing Q486902...
# Processing Q2637489...
# Processing Q19933904...
# Processing Q12177156...
# Processing Q86970...
# Processing Q755992...
# Processing Q529985...
# Processing Q609089...
# Processing Q238170...
# Processing Q213371...
# Processing Q846759...
# Processing Q22683173...
# Processing Q159653...
# Processing Q2477501...
# Processing Q974572...
# Processing Q84227...
# Processing Q1211136...
# Processing Q39599...
# Processing Q15240741...
# Processing Q242657...
# Processing Q186608...
# Processing Q42458...
# Processing Q6694023...
# Processing Q1339916...
# Processing Q103531...
# Processing Q466686...
# Processing Q179635...
# Processing Q428867...
# Processing Q254329...
# Processing Q1823579...
# Processing Q209402...
# Processing Q141022...
# Processing Q1142276...
# Processing Q838055...
# Processing Q906367...
# Processing Q739962...
# Processing Q2101...
# Processing Q578430...
# Processing Q837940...
# Processing Q159731...
# Processing Q41803...
# Processing Q179836...
# Processing Q483666...
# Processing Q16259746...
# Processing Q233974...
# Processing Q6485344...
# Processing Q25406...
# Processing Q255996...
# Processing Q7236691...
# Processing Q1332690...
# Processing Q160329...
# Processing Q3129354...
# Processing Q214850...
# Processing Q321237...
# Processing Q230963...
# Processing Q7424019...
# Processing Q1366301...
# Processing Q172466...
# Processing Q1503556...
# Processing Q169893...
# Processing Q174984...
# Processing Q122366...
# Processing Q185243...
# Processing Q193972...
# Processing Q845744...
# Processing Q1057093...
# Processing Q4097...
# Processing Q3230...
# Processing Q57020342...
# Processing Q3259177...
# Processing Q681449...
# Processing Q877100...
# Processing Q6510488...
# Processing Q66900467...
# Processing Q186559...
# Processing Q846667...
# Processing Q2357982...
# Processing Q766722...
# Processing Q25288...
# Processing Q1754650...
# Processing Q902054...
# Processing Q174728...
# Processing Q216817...
# Processing Q199687...
# Processing Q223325...
# Processing Q1326722...
# Processing Q4302108...
# Processing Q205928...
# Processing Q1536431...
# Processing Q212881...
# Processing Q13473395...
# Processing Q727898...
# Processing Q1052397...
# Processing Q192005...
# Processing Q245627...
# Processing Q390314...
# Processing Q186300...
# Processing Q2396526...
# Processing Q18370...
# Processing Q2165620...
# Processing Q11372...
# Processing Q1130571...
# Processing Q1276273...
# Processing Q908652...
# Processing Q184550...
# Processing Q185553...
# Processing Q260126...
# Processing Q2986369...
# Processing Q1241734...
# Processing Q1370994...
# Processing Q1130414...
# Processing Q215589...
# Processing Q900653...
# Processing Q437882...
# Processing Q192794...
# Processing Q911364...
# Processing Q103382...
# Processing Q2497658...
# Processing Q177612...
# Processing Q177831...
# Processing Q175233...
# Processing Q1665115...
# Processing Q483769...
# Processing Q1309670...
# Processing Q17086396...
# Processing Q27137...
# Processing Q208598...
# Processing Q186167...
# Processing Q533668...
# Processing Q2142457...
# Processing Q331824...
# Processing Q5467462...
# Processing Q1113650...
# Processing Q1468412...
# Processing Q25303603...
# Processing Q2739914...
# Processing Q419978...
# Processing Q752732...
# Processing Q172145...
# Processing Q724095...
# Processing Q143518...
# Processing Q834020...
# Processing Q1042470...
# Processing Q1895983...
# Processing Q2620282...
# Processing Q487875...
# Processing Q7281380...
# Processing Q890225...
# Processing Q14290846...
# Processing Q178668...
# Processing Q193460...
# Processing Q21143897...
# Processing Q285804...
# Processing Q334760...
# Processing Q237604...
# Processing Q521729...
# Processing Q127993...
# Processing Q172840...
# Processing Q269323...
# Processing Q4785354...
# Processing Q247932...
# Processing Q4774931...
# Processing Q2660535...
# Processing Q3926180...
# Processing Q215022...
# Processing Q17091707...
# Processing Q1193821...
# Processing Q54910469...
# Processing Q24962483...
# Processing Q134574...
# Processing Q895901...
# Processing Q78318...
# Processing Q657936...
# Processing Q2991689...
# Processing Q1201886...
# Processing Q3630500...
# Processing Q3407632...
# Processing Q829522...
# Processing Q849940...
# Processing Q862458...
# Processing Q28352...
# Processing Q860615...
# Processing Q2992500...
# Processing Q4130...
# Processing Q188403...
# Processing Q5979196...
# Processing Q188721...
# Processing Q160398...
# Processing Q2916980...
# Processing Q232431...
# Processing Q47434...
# Processing Q680...
# Processing Q182767...
# Processing Q1538262...
# Processing Q190382...
# Processing Q13365511...
# Processing Q1061251...
# Processing Q192690...
# Processing Q28967...
# Processing Q658065...
# Processing Q216320...
# Processing Q10886678...
# Processing Q1854812...
# Processing Q380528...
# Processing Q193760...
# Processing Q193523...
# Processing Q206021...
# Processing Q192819...
# Processing Q272626...
# Processing Q737004...
# Processing Q749467...
# Processing Q109856...
# Processing Q828284...
# Processing Q7465774...
# Processing Q201805...
# Processing Q609501...
# Processing Q245031...
# Processing Q988780...
# Processing Q37642...
# Processing Q133267...
# Processing Q210028...
# Processing Q1184955...
# Processing Q1072553...
# Processing Q747702...
# Processing Q248929...
# Processing Q901559...
# Processing Q1929294...
# Processing Q910483...
# Processing Q2549249...
# Processing Q3738063...
# Processing Q847354...
# Processing Q105902...
# Processing Q360475...
# Processing Q1068172...
# Processing Q319686...
# Processing Q23645...
# Processing Q944873...
# Processing Q461466...
# Processing Q6653802...
# Processing Q660848...
# Processing Q898756...
# Processing Q1151645...
# Processing Q3819767...
# Processing Q5459058...
# Processing Q1437483...
# Processing Q3251738...
# Processing Q82811...
# Processing Q194356...
# Processing Q4112212...
# Processing Q1142562...
# Processing Q550341...
# Processing Q12485...
# Processing Q8962...
# Processing Q1413914...
# Processing Q192288...
# Processing Q1510587...
# Processing Q27521...
# Processing Q2590381...
# Processing Q5426838...
# Processing Q647887...
# Processing Q329273...
# Processing Q15606633...
# Processing Q138597...
# Processing Q8424...
# Processing Q747066...
# Processing Q284657...
# Processing Q3003861...
# Processing Q484790...
# Processing Q2902868...
# Processing Q483674...
# Processing Q2060691...
# Processing Q722799...
# Processing Q662636...
# Processing Q285949...
# Processing Q3375768...
# Processing Q185153...
# Processing Q673253...
# Processing Q1473449...
# Processing Q901737...
# Processing Q192112...
# Processing Q487623...
# Processing Q806352...
# Processing Q210719...
# Processing Q1127242...
# Processing Q900392...
# Processing Q1384211...
# Processing Q51366...
# Processing Q215932...
# Processing Q792548...
# Processing Q18387741...
# Processing Q21014200...
# Processing Q652571...
# Processing Q507732...
# Processing Q115117502...
# Processing Q75545229...
# Processing Q1498677...
# Processing Q116754...
# Processing Q1256500...
# Processing Q51363...
# Processing Q1049029...
# Processing Q1364409...
# Processing Q773078...
# Processing Q4497727...
# Processing Q693104...
# Processing Q6987233...
# Processing Q1269129...
# Processing Q1134348...
# Processing Q375175...
# Processing Q543682...
# Processing Q1751823...
# Processing Q902090...
# Processing Q622779...
# Processing Q6582994...
# Processing Q43393...
# Processing Q133846...
# Processing Q212126...
# Processing Q3099902...
# Processing Q2193337...
# Processing Q170196...
# Processing Q285033...
# Processing Q282791...
# Processing Q332007...
# Processing Q5368744...
# Processing Q4379531...
# Processing Q107715...
# Processing Q911284...
# Processing Q5434480...
# Processing Q23664...
# Processing Q655904...
# Processing Q899552...
# Processing Q2165236...
# Processing Q1190763...
# Processing Q163214...
# Processing Q764228...
# Processing Q898280...
# Processing Q325401...
# Processing Q2335216...
# Processing Q1047702...
# Processing Q188910...
# Processing Q504186...
# Processing Q831774...
# Processing Q11027905...
# Processing Q102573...
# Processing Q1130745...
# Processing Q756033...
# Processing Q978234...
# Processing Q616432...
# Processing Q815306...
# Processing Q192593...
# Processing Q176066...
# Processing Q271707...
# Processing Q2221081...
# Processing Q825643...
# Processing Q1431247...
# Processing Q241735...
# Processing Q1148098...
# Processing Q45789...
# Processing Q223776...
# Processing Q107450...
# Processing Q6501076...
# Processing Q864015...
# Processing Q662790...
# Processing Q115925888...
# Processing Q81242...
# Processing Q200286...
# Processing Q898574...
# Processing Q898896...
# Processing Q533281...
# Processing Q175029...
# Processing Q851016...
# Processing Q856292...
# Processing Q1203476...
# Processing Q858624...
# Processing Q177807...
# Processing Q302518...
# Processing Q113000019...
# Processing Q221764...
# Processing Q194523...
# Processing Q619699...
# Processing Q215612...
# Processing Q1137903...
# Processing Q13590494...
# Processing Q111059...
# Processing Q14632398...
# Processing Q371907...
# Processing Q868425...
# Processing Q104840803...
# Processing Q185674...
# Processing Q187241...
# Processing Q4883199...
# Processing Q240553...
# Processing Q5561244...
# Processing Q1190143...
# Processing Q1250263...
# Processing Q208554...
# Processing Q241687...
# Processing Q464949...
# Processing Q120005...
# Processing Q49002...
# Processing Q1335241...
# Processing Q1049613...
# Processing Q560430...
# Processing Q60661...
# Processing Q1145895...
# Processing Q57145...
# Processing Q1331774...
# Processing Q505735...
# Processing Q187465...
# Processing Q4455142...
# Processing Q165939...
# Processing Q92251...
# Processing Q123530727...
# Processing Q8067817...
# Processing Q1876815...
# Processing Q125526...
# Processing Q1146448...
# Processing Q13405516...
# Processing Q185329...
# Processing Q165848...
# Processing Q1398201...
# Processing Q1044799...
# Processing Q450404...
# Processing Q16733810...
# Processing Q4373292...
# Processing Q194433...
# Processing Q579900...
# Processing Q4119076...
# Processing Q11438...
# Processing Q29166...
# Processing Q1570027...
# Processing Q11271324...
# Processing Q867448...
# Processing Q862682...
# Processing Q212923...
# Processing Q663314...
# Processing Q837505...
# Processing Q669532...
# Processing Q13824...
# Processing Q1413102...
# Processing Q3879445...
# Processing Q217030...
# Processing Q3137239...
# Processing Q1259526...
# Processing Q238323...
# Processing Q584049...
# Processing Q1063567...
# Processing Q752193...
# Processing Q1143773...
# Processing Q258659...
# Processing Q898268...
# Processing Q846785...
# Processing Q855112...
# Processing Q170475...
# Processing Q48837509...
# Processing Q2984318...
# Processing Q3814108...
# Processing Q205805...
# Processing Q865821...
# Processing Q843503...
# Processing Q3445240...
# Processing Q365578...
# Processing Q169336...
# Processing Q1135540...
# Processing Q5233465...
# Processing Q2909684...
# Processing Q126017...
# Processing Q1621273...
# Processing Q3505263...
# Processing Q27165...
# Processing Q4505651...
# Processing Q483788...
# Processing Q1569795...
# Processing Q198099...
# Processing Q503869...
# Processing Q379231...
# Processing Q585745...
# Processing Q721706...
# Processing Q1079524...
# Processing Q281017...
# Processing Q605529...
# Processing Q3523932...
# Processing Q1431014...
# Processing Q48179...
# Processing Q808592...
# Processing Q1164612...
# Processing Q431335...
# Processing Q180241...
# Processing Q3561227...
# Processing Q1335249...
# Processing Q2297853...
# Processing Q3517751...
# Processing Q613845...
# Processing Q1065883...
# Processing Q471702...
# Processing Q10861254...
# Processing Q2510765...
# Processing Q2937190...
# Processing Q112835448...
# Processing Q654182...
# Processing Q1399710...
# Processing Q19574791...
# Processing Q609542...
# Processing Q626707...
# Processing Q574780...
# Processing Q5017052...
# Processing Q2373354...
# Processing Q177596...
# Processing Q5294921...
# Processing Q160020...
# Processing Q824852...
# Processing Q193147...
# Processing Q243354...
# Processing Q2663606...
# Processing Q894014...
# Processing Q847609...
# Processing Q55632234...
# Processing Q3381809...
# Processing Q3083131...
# Processing Q908669...
# Processing Q959840...
# Processing Q177784...
# Processing Q184876...
# Processing Q8214306...
# Processing Q207721...
# Processing Q1191271...
# Processing Q1588205...
# Processing Q1149766...
# Processing Q735135...
# Processing Q2035889...
# Processing Q3604146...
# Processing Q661248...
# Processing Q188392...
# Processing Q691978...
# Processing Q1437042...
# Processing Q154345...
# Processing Q737120...
# Processing Q1570137...
# Processing Q222971...
# Processing Q2943139...
# Processing Q4925317...
# Processing Q850283...
# Processing Q6750062...
# Processing Q1114429...
# Processing Q840916...
# Processing Q245341...
# Processing Q79782...
# Processing Q6636894...
# Processing Q1406191...
# Processing Q1240867...
# Processing Q188463...
# Processing Q3522756...
# Processing Q182893...
# Processing Q5916...
# Processing Q1376614...
# Processing Q367196...
# Processing Q23135326...
# Processing Q1913293...
# Processing Q1470145...
# Processing Q901707...
# Processing Q739173...
# Processing Q49901...
# Processing Q2164635...
# Processing Q1482138...
# Processing Q642488...
# Processing Q1529808...
# Processing Q2698490...
# Processing Q234904...
# Processing Q221221...
# Processing Q107333413...
# Processing Q1337763...
# Processing Q915217...
# Processing Q234072...
# Processing Q1706914...
# Processing Q584304...
# Processing Q835065...
# Processing Q166583...
# Processing Q543413...
# Processing Q325393...
# Processing Q3062485...
# Processing Q904893...
# Processing Q192940...
# Processing Q1199050...
# Processing Q899033...
# Processing Q6784057...
# Processing Q624587...
# Processing Q907564...
# Processing Q917713...
# Processing Q902045...
# Processing Q274116...
# Processing Q909960...
# Processing Q1027878...
# Processing Q908584...
# Processing Q910035...
# Processing Q2351504...
# Processing Q657586...
# Processing Q560811...
# Processing Q321098...
# Processing Q831024...
# Processing Q10862754...
# Processing Q532078...
# Processing Q101395...
# Processing Q9300786...
# Processing Q898732...
# Processing Q1054240...
# Processing Q60024...
# Processing Q5518616...
# Processing Q1037959...
# Processing Q3350745...
# Processing Q2812386...
# Processing Q6155075...
# Processing Q1478382...
# Processing Q649803...
# Processing Q468809...
# Processing Q586386...
# Processing Q217361...
# Processing Q5199275...
# Processing Q692457...
# Processing Q1126161...
# Processing Q4118037...
# Processing Q3236003...
# Processing Q1760468...
# Processing Q193463...
# Processing Q83331...
# Processing Q332868...
# Processing Q486921...
# Processing Q141160...
# Processing Q486802...
# Processing Q2672013...
# Processing Q392416...
# Processing Q212111...
# Processing Q4162444...
# Processing Q177493...
# Processing Q523647...
# Processing Q922672...
# Processing Q7705501...
# Processing Q760106...
# Processing Q5341956...
# Processing Q1061524...
# Processing Q57063...
# Processing Q1027847...
# Processing Q182031...
# Processing Q744771...
# Processing Q16859309...
# Processing Q900117...
# Processing Q1230543...
# Processing Q354718...
# Processing Q541008...
# Processing Q585777...
# Processing Q729856...
# Processing Q1715792...
# Processing Q1076013...
# Processing Q1048114...
# Processing Q77647984...
# Processing Q5190506...
# Processing Q326557...
# Processing Q6510183...
# Processing Q653294...
# Processing Q13222844...
# Processing Q946764...
# Processing Q622381...
# Processing Q871279...
# Processing Q3116769...
# Processing Q648961...
# Processing Q153224...
# Processing Q2051612...
# Processing Q306639...
# Processing Q14916030...
# Processing Q273163...
# Processing Q185098...
# Processing Q180173...
# Processing Q1356355...
# Processing Q390528...
# Processing Q590051...
# Processing Q649036...
# Processing Q741255...
# Processing Q2918240...
# Processing Q900918...
# Processing Q944755...
# Processing Q612206...
# Processing Q741979...
# Processing Q4188...
# Processing Q1783143...
# Processing Q1139740...
# Processing Q604374...
# Processing Q2373057...
# Processing Q16821605...
# Processing Q1540138...
# Processing Q15900993...
# Processing Q214967...
# Processing Q473195...
# Processing Q841267...
# Processing Q13633683...
# Processing Q1138138...
# Processing Q1431196...
# Processing Q552311...
# Processing Q179572...
# Processing Q644405...
# Processing Q452091...
# Processing Q182854...
# Processing Q466824...
# Processing Q25312612...
# Processing Q1248980...
# Processing Q1972470...
# Processing Q288903...
# Processing Q1182714...
# Processing Q370046...
# Processing Q105821893...
# Processing Q310773...
# Processing Q835975...
# Processing Q77078...
# Processing Q473322...
# Processing Q201762...
# Processing Q756307...
# Processing Q191645...
# Processing Q5358074...
# Processing Q1476020...
# Processing Q102626...
# Processing Q212120...
# Processing Q12794416...
# Processing Q1231632...
# Processing Q190983...
# Processing Q160362...
# Processing Q18346...
# Processing Q191021...
# Processing Q3658620...
# Processing Q11778649...
# Processing Q2985634...
# Processing Q6754...
# Processing Q3062477...
# Processing Q170431...
# Processing Q15726150...
# Processing Q899559...
# Processing Q3707396...
# Processing Q901106...
# Processing Q230937...
# Processing Q830654...
# Processing Q584537...
# Processing Q510427...
# Processing Q193139...
# Processing Q427085...
# Processing Q2358974...
# Processing Q1490646...
# Processing Q1465231...
# Processing Q2122463...
# Processing Q747713...
# Processing Q2303209...
# Processing Q967772...
# Processing Q109918184...
# Processing Q1186765...
# Processing Q1295986...
# Processing Q907271...
# Processing Q851014...
# Processing Q909999...
# Processing Q736895...
# Processing Q132146...
# Processing Q23808069...
# Processing Q691463...
# Processing Q191073...
# Processing Q1196575...
# Processing Q23000947...
# Processing Q1801562...
# Processing Q186634...
# Processing Q1047822...
# Processing Q505668...
# Processing Q202151...
# Processing Q15115271...
# Processing Q1009906...
# Processing Q195533...
# Processing Q25820...
# Processing Q1077753...
# Processing Q5454249...
# Processing Q184631...
# Processing Q109910...
# Processing Q1603273...
# Processing Q2268240...
# Processing Q1243208...
# Processing Q107617...
# Processing Q2249209...
# Processing Q583152...
# Processing Q606855...
# Processing Q62932...
# Processing Q108000...
# Processing Q106433964...
# Processing Q1550781...
# Processing Q1713773...
# Processing Q1068747...
# Processing Q647227...
# Processing Q1579556...
# Processing Q183397...
# Processing Q279082...
# Processing Q206037...
# Processing Q264224...
# Processing Q635982...
# Processing Q83041...
# Processing Q261967...
# Processing Q3780403...
# Processing Q7696800...
# Processing Q11170087...
# Processing Q1770333...
# Processing Q1812910...
# Processing Q900371...
# Processing Q6918638...
# Processing Q2304023...
# Processing Q5380799...
# Processing Q636889...
# Processing Q1429077...
# Processing Q3238797...
# Processing Q1412452...
# Processing Q2797526...
# Processing Q1034880...
# Processing Q4679069...
# Processing Q148319...
# Processing Q573880...
# Processing Q1978718...
# Processing Q2297576...
# Processing Q899670...
# Processing Q468846...
# Processing Q208641...
# Processing Q204170...
# Processing Q55608358...
# Processing Q2538708...
# Processing Q143885...
# Processing Q749542...
# Processing Q25343...
# Processing Q7100...
# Processing Q230895...
# Processing Q902086...
# Processing Q900689...
# Processing Q603198...
# Processing Q6921783...
# Processing Q863109...
# Processing Q616172...
# Processing Q18390471...
# Processing Q205897...
# Processing Q4431229...
# Processing Q30593148...
# Processing Q266995...
# Processing Q75828...
# Processing Q1334758...
# Processing Q87524...
# Processing Q2264390...
# Processing Q19361335...
# Processing Q4116311...
# Processing Q15079395...
# Processing Q1575131...
# Processing Q1414409...
# Processing Q1670575...
# Processing Q709931...
# Processing Q939225...
# Processing Q6503449...
# Processing Q491409...
# Processing Q5598005...
# Processing Q7883828...
# Processing Q1931232...
# Processing Q5951321...
# Processing Q7269047...
# Processing Q1382125...
# Processing Q9047...
# Processing Q3310692...
# Processing Q124340...
# Processing Q3045751...
# Processing Q22091918...
# Processing Q2394680...
# Processing Q3523897...
# Processing Q6643258...
# Processing Q2122243...
# Processing Q2599934...
# Processing Q6795892...
# Processing Q1589...
# Processing Q682321...
# Processing Q994122...
# Processing Q493956...
# Processing Q17009773...
# Processing Q93479...
# Processing Q1758384...
# Processing Q910990...
# Processing Q2726733...
# Processing Q462477...
# Processing Q3115080...
# Processing Q2738925...
# Processing Q912471...
# Processing Q2287715...
# Processing Q375553...
# Processing Q902354...
# Processing Q1032070...
# Processing Q758291...
# Processing Q7643248...
# Processing Q364997...
# Processing Q1277959...
# Processing Q2102938...
# Processing Q1425059...
# Processing Q1477639...
# Processing Q2344775...
# Processing Q664424...
# Processing Q3283...
# Processing Q310759...
# Processing Q187140...
# Processing Q2875693...
# Processing Q260060...
# Processing Q983385...
# Processing Q422584...
# Processing Q7173039...
# Processing Q848501...
# Processing Q379788...
# Processing Q13553575...
# Processing Q153243...
# Processing Q715746...
# Processing Q5120022...
# ...
# Processing Q16939311...
# Processing Q2450730...
# Processing Q5525402...
# Processing Q269492...
# Processing Q4163318...
# Processing Q5567394...
# Processing Q6636278...
# Processing Q11141463...
# Processing Q1054585...
# Processing Q560778...
# Processing Q15136073...
# Processing Q5378429...
# Processing Q1377101...
# Processing Q7631351...
# Processing Q498957...
# Processing Q7186189...
# Processing Q84292...
# Processing Q4682912...
# Processing Q8042857...
# Processing Q1192097...
# Processing Q2630994...
# Processing Q15916419...
# Processing Q2993351...
# Processing Q3678789...
# Processing Q4897186...
# Processing Q19314...
# Processing Q20736125...
# Processing Q57554...
# Processing Q1573329...
# Processing Q1108221...
# Processing Q30325097...
# Processing Q877096...
# Processing Q2917619...
# Processing Q1941852...
# Processing Q7648839...
# Processing Q3823104...
# Processing Q5604179...
# Processing Q1722586...
# Processing Q28228095...
# Processing Q550926...
# Processing Q4027132...
# Processing Q898535...
# Processing Q2624879...
# Processing Q13690522...
# Processing Q1724378...
# Processing Q941085...
# Processing Q53996643...
# Processing Q28454272...
# Processing Q3300028...
# Processing Q23582440...
# Processing Q7002983...
# Processing Q277967...
# Processing Q545142...
# Processing Q1136352...
# Processing Q564897...
# Processing Q3424284...
# Processing Q2628009...
# Processing Q105580...
# Processing Q1192842...
# Processing Q500515...
# Processing Q3182777...
# Processing Q2614611...
# Processing Q770766...
# Processing Q477130...
# Processing Q3140601...
# Processing Q1240181...
# Processing Q55619447...
# Processing Q17156810...
# Processing Q1718412...
# Processing Q111915649...
# Processing Q6557437...
# Processing Q7445303...
# Processing Q1547424...
# Processing Q124254113...
# Processing Q628065...
# Processing Q78510...
# Processing Q4257501...
# Processing Q17029447...
# Processing Q357527...
# Processing Q5111954...
# Processing Q1509906...
# Processing Q5223514...
# Processing Q7642959...
# Processing Q3045294...
# Processing Q1907558...
# Processing Q5234241...
# Processing Q3054654...
# Processing Q7643352...
# Processing Q898383...
# Processing Q1626812...
# Processing Q383606...
# Processing Q1353262...
# Processing Q190766...
# Processing Q4517...
# Processing Q318037...
# Processing Q7778426...
# Processing Q7269069...
# Processing Q1079806...
# Processing Q2578228...
# Processing Q15704567...
# Processing Q1407411...
# Processing Q757625...
# Processing Q14613383...
# Processing Q7168332...
# Processing Q6452502...
# Processing Q332105...
# Processing Q118801...
# Processing Q3109934...
# Processing Q176851...
# Processing Q1115145...
# Processing Q446862...
# Processing Q3097928...
# Processing Q1687989...
# Processing Q440619...
# Processing Q2556346...
# Processing Q75009177...
# Processing Q5755487...
# Processing Q1621662...
# Processing Q10941823...
# Processing Q1507638...
# Processing Q1969721...
# Processing Q7239845...
# Processing Q581516...
# Processing Q745837...
# Processing Q131729...
# Processing Q1468684...
# Processing Q1708214...
# Processing Q261552...
# Processing Q116879...
# Processing Q1473433...
# Processing Q1417604...
# Processing Q2614323...
# Processing Q1340031...
# Processing Q7075180...
# Processing Q176449...
# Processing Q240708...
# Processing Q899581...
# Processing Q124853046...
# Processing Q7795912...
# Processing Q505530...
# Processing Q1341668...
# Processing Q1062974...
# Processing Q2707219...
# Processing Q2890543...
# Processing Q1120908...
# Processing Q4674696...
# Processing Q7294230...
# Processing Q1096106...
# Processing Q2081419...
# Processing Q2880612...
# Processing Q4252981...
# Processing Q1639946...
# Processing Q5159402...
# Processing Q3796745...
# Processing Q331466...
# Processing Q1426632...
# Processing Q7174049...
# Processing Q571133...
# Processing Q2149374...
# Processing Q1019218...
# Processing Q4332595...
# Processing Q1570591...
# Processing Q114942532...
# Processing Q991823...
# Processing Q14710076...
# Processing Q2723682...
# Processing Q219207...
# Processing Q5914418...
# Processing Q5958048...
# Processing Q153210...
# Processing Q899089...
# Processing Q113631710...
# Processing Q9298968...
# Processing Q6701881...
# Processing Q6761598...
# Processing Q1455803...
# Processing Q4536303...
# Processing Q48995751...
# Processing Q1359207...
# Processing Q836938...
# Processing Q4330561...
# Processing Q3272401...
# Processing Q606387...
# Processing Q22668086...
# Processing Q3966083...
# Processing Q1546281...
# Processing Q76541...
# Processing Q7433294...
# Processing Q47322213...
# Processing Q1190146...
# Processing Q1406423...
# Processing Q901095...
# Processing Q911664...
# Processing Q4228979...
# Processing Q3055345...
# Processing Q899249...
# Processing Q900625...
# Processing Q899127...
# Processing Q959336...
# Processing Q334265...
# Processing Q2142864...
# Processing Q906347...
# Processing Q2054937...
# Processing Q2797953...
# Processing Q518459...
# Processing Q17101964...
# Processing Q175906...
# Processing Q3635842...
# Processing Q922419...
# Processing Q2066340...
# Processing Q2835770...
# Processing Q7140502...
# Processing Q3136993...
# Processing Q373065...
# Processing Q513656...
# Processing Q7315745...
# Processing Q5450142...
# Processing Q2799395...
# Processing Q15850900...
# Processing Q335593...
# Processing Q112876434...
# Processing Q16917817...
# Processing Q5256919...
# Processing Q3050597...
# Processing Q7642930...
# Processing Q391639...
# Processing Q1393227...
# Processing Q3830212...
# Processing Q2140269...
# Processing Q1413752...
# Processing Q2257916...
# Processing Q253897...
# Processing Q1777346...
# Processing Q1660224...
# Processing Q355423...
# Processing Q1607213...
# Processing Q1543991...
# Processing Q115801008...
# Processing Q1669228...
# Processing Q621615...
# Processing Q43948...
# Processing Q2142826...
# Processing Q3269677...
# Processing Q13534105...
# Processing Q20707568...
# Processing Q691387...
# Processing Q889796...
# Processing Q5437040...
# Processing Q1391370...
# Processing Q6033847...
# Processing Q901448...
# Processing Q2009618...
# Processing Q2585683...
# Processing Q1344778...
# Processing Q1266034...
# Processing Q1783425...
# Processing Q1142411...
# Processing Q76474...
# Processing Q2474670...
# Processing Q4797877...
# Processing Q5316694...
# Processing Q623093...
# Processing Q7100770...
# Processing Q898542...
# Processing Q909741...
# Processing Q2165889...
# Processing Q7882927...
# Processing Q7820109...
# Processing Q7800849...
# Processing Q2401305...
# Processing Q541895...
# Processing Q295430...
# Processing Q97943607...
# Processing Q3405827...
# Processing Q2527923...
# Processing Q251524...
# Processing Q5638576...
# Processing Q1746063...
# Processing Q96379188...
# Processing Q3565881...
# Processing Q928582...
# Processing Q2347139...
# Processing Q368442...
# Processing Q7746627...
# Processing Q28408358...
# Processing Q256839...
# Processing Q1457297...
# Processing Q2908602...
# Processing Q19597107...
# Processing Q2658857...
# Processing Q3822426...
# Processing Q44111...
# Processing Q2821580...
# Processing Q2481895...
# Processing Q7536964...
# Processing Q2361408...
# Processing Q3265048...
# Processing Q3382037...
# Processing Q38080891...
# Processing Q2979093...
# Processing Q733073...
# Processing Q11757549...
# Processing Q60519967...
# Processing Q6897281...
# Processing Q4676887...
# Processing Q409227...
# Processing Q5242756...
# Processing Q15134248...
# Processing Q22811512...
# Processing Q6418927...
# Processing Q1900815...
# Processing Q762018...
# Processing Q728969...
# Processing Q1642137...
# Processing Q2087545...
# Processing Q559573...
# Processing Q1072476...
# Processing Q28784...
# Processing Q1292425...
# Processing Q5174319...
# Processing Q6188937...
# Processing Q4966469...
# Processing Q11168306...
# Processing Q2302080...
# Processing Q1397391...
# Processing Q175593...
# Processing Q20714000...
# Processing Q2875956...
# Processing Q2000761...
# Processing Q1667940...
# Processing Q852212...
# Processing Q4340379...
# Processing Q5585891...
# Processing Q5380658...
# Processing Q1376436...
# Processing Q1770567...
# Processing Q2197698...
# Processing Q2748917...
# Processing Q3543687...
# Processing Q1356372...
# Processing Q124972891...
# Processing Q4147361...
# Processing Q1144923...
# Processing Q5646976...
# Processing Q13424796...
# Processing Q634407...
# Processing Q17119376...
# Processing Q19898420...
# Processing Q7941898...
# Processing Q7783031...
# Processing Q981768...
# Processing Q1891460...
# Processing Q1057006...
# Processing Q104864008...
# Processing Q26466040...
# Processing Q7269101...
# Processing Q916091...
# Processing Q7201746...
# Processing Q6256824...
# Processing Q17004315...
# Processing Q175932...
# Processing Q510190...
# Processing Q863571...
# Processing Q315422...
# Processing Q7994252...
# Processing Q900515...
# Processing Q1280936...
# Processing Q865663...
# Processing Q28452372...
# Processing Q81121...
# Processing Q693545...
# Processing Q900475...
# Processing Q58328...
# Processing Q864746...
# Processing Q1401936...
# Processing Q179852...
# Processing Q2420179...
# Processing Q902458...
# Processing Q2466686...
# Processing Q9691942...
# Processing Q5349781...
# Processing Q899173...
# Processing Q551338...
# Processing Q2499617...
# Processing Q1907514...
# Processing Q7980541...
# Processing Q2339425...
# Processing Q901768...
# Processing Q2166583...
# Processing Q5386958...
# Processing Q618632...
# Processing Q7638720...
# Processing Q16677669...
# Processing Q2623868...
# Processing Q2576923...
# Processing Q4356867...
# Processing Q1751397...
# Processing Q6151773...
# Processing Q1365721...
# Processing Q4394061...
# Processing Q2383018...
# Processing Q7269086...
# Processing Q891656...
# Processing Q1586184...
# Processing Q2622608...
# Processing Q7833984...
# Processing Q64748821...
# Processing Q1396604...
# Processing Q206379...
# Processing Q1548585...
# Processing Q2915278...
# Processing Q390003...
# Processing Q15119237...
# Processing Q420906...
# Processing Q2908408...
# Processing Q3030666...
# Processing Q744057...
# Processing Q119133...
# Processing Q290420...
# Processing Q201452...
# Processing Q898351...
# Processing Q28823458...
# Processing Q1267170...
# Processing Q547346...
# Processing Q506922...
# Processing Q2016597...
# Processing Q6495541...
# Processing Q2829907...
# Processing Q428940...
# Processing Q5358004...
# Processing Q7198816...
# Processing Q2124139...
# Processing Q1156878...
# Processing Q904273...
# Processing Q76770...
# Processing Q41519...
# Processing Q109968206...
# Processing Q1349364...
# Processing Q5419628...
# Processing Q7259676...
# Processing Q5317033...
# Processing Q467980...
# Processing Q1173201...
# Processing Q900711...
# Processing Q1143841...
# Processing Q444789...
# Processing Q25304680...
# Processing Q1150290...
# Processing Q653486...
# Processing Q2478109...
# Processing Q2988941...
# Processing Q182460...
# Processing Q6440...
# Processing Q678322...
# Processing Q1364131...
# Processing Q3604864...
# Processing Q20049851...
# Processing Q28555856...
# Processing Q1571298...
# Processing Q13557555...
# Processing Q735136...
# Processing Q607421...
# Processing Q386803...
# Processing Q7045630...
# Processing Q1065189...
# Processing Q65296045...
# Processing Q16186816...
# Processing Q902168...
# Processing Q489349...
# Processing Q1093427...
# Processing Q7408338...
# Processing Q1424759...
# Processing Q128418...
# Processing Q4764527...
# Processing Q424019...
# Processing Q28976188...
# Processing Q10314191...
# Processing Q722128...
# Processing Q97357778...
# Processing Q857130...
# Processing Q56805406...
# Processing Q1890674...
# Processing Q10497232...
# Processing Q249023...
# Processing Q787619...
# Processing Q13469181...
# Processing Q6856168...
# Processing Q4035626...
# Processing Q2601129...
# Processing Q425705...
# Processing Q5447117...
# Processing Q1477313...
# Processing Q306600...
# Processing Q24717009...
# Processing Q916258...
# Processing Q5452017...
# Processing Q6625335...
# Processing Q946666...
# Processing Q902936...
# Processing Q917476...
# Processing Q1319010...
# Processing Q866218...
# Processing Q7564743...
# Processing Q166253...
# Processing Q58256908...
# Processing Q2913714...
# Processing Q2737837...
# Processing Q1704731...
# Processing Q156942...
# Processing Q17083130...
# Processing Q1357688...
# Processing Q908360...
# Processing Q910690...
# Processing Q57072...
# Processing Q704319...
# Processing Q7335725...
# Processing Q918398...
# Processing Q956736...
# Processing Q6497909...
# Processing Q56929271...
# Processing Q1076995...
# Processing Q15992992...
# Processing Q58914114...
# Processing Q2946193...
# Processing Q7186280...
# Processing Q28821...
# Processing Q18746151...
# Processing Q7924640...
# Processing Q375680...
# Processing Q109231979...
# Processing Q474194...
# Processing Q939954...
# Processing Q6807657...
# Processing Q425771...
# Processing Q6675557...
# Processing Q4291887...
# Processing Q37631899...
# Processing Q107420...
# Processing Q184014...
# Processing Q4106859...
# Processing Q1754137...
# Processing Q3866303...
# Processing Q123452568...
# Processing Q1783416...
# Processing Q873499...
# Processing Q26370...
# Processing Q17395359...
# Processing Q3510632...
# Processing Q44415...
# Processing Q727443...
# Processing Q3218288...
# Processing Q193168...
# Processing Q332729...
# Processing Q2367841...
# Processing Q5487060...
# Processing Q725309...
# Processing Q48780746...
# Processing Q655405...
# Processing Q8565160...
# Processing Q544431...
# Processing Q12027631...
# Processing Q117701...
# Processing Q17103302...
# Processing Q43370112...
# Processing Q1144416...
# Processing Q2152581...
# Processing Q2917212...
# Processing Q1541238...
# Processing Q197964...
# Processing Q306395...
# Processing Q4118792...
# Processing Q1240491...
# Processing Q5961276...
# Processing Q5366429...
# Processing Q576221...
# Processing Q1201087...
# Processing Q4468204...
# Processing Q1942321...
# Processing Q7922774...
# Processing Q28509...
# Processing Q3180597...
# Processing Q4396596...
# Processing Q114764505...
# Processing Q901697...
# Processing Q900638...
# Processing Q104488204...
# Processing Q21775698...
# Processing Q1754040...
# Processing Q2360668...
# Processing Q2632607...
# Processing Q911951...
# Processing Q277816...
# Processing Q323331...
# Processing Q5240134...
# Processing Q2166376...
# Processing Q69195...
# Processing Q52669637...
# Processing Q1065721...
# Processing Q382760...
# Processing Q448559...
# Processing Q4666993...
# Processing Q5597987...
# Processing Q3488289...
# Processing Q4901639...
# Processing Q179201...
# Processing Q2516739...
# Processing Q2141325...
# Processing Q51643183...
# Processing Q1937401...
# Processing Q241822...
# Processing Q1394769...
# Processing Q2787176...
# Processing Q2532943...
# Processing Q3859817...
# Processing Q1929925...
# Processing Q610001...
# Processing Q2639620...
# Processing Q191799...
# Processing Q1771119...
# Processing Q259517...
# Processing Q339281...
# Processing Q1323473...
# Processing Q48816584...
# Processing Q7391872...
# Processing Q1584373...
# Processing Q6712300...
# Processing Q7269518...
# Processing Q674038...
# Processing Q1076457...
# Processing Q1439803...
# Processing Q6786849...
# Processing Q470792...
# Processing Q28370110...
# Processing Q4894840...
# Processing Q1153833...
# Processing Q7252067...
# Processing Q131360064...
# Processing Q44717877...
# Processing Q134141...
# Processing Q48965606...
# Processing Q17084000...
# Processing Q114560...
# Processing Q7068046...
# Processing Q507425...
# Processing Q3746869...
# Processing Q15044673...
# Processing Q1684776...
# Processing Q57125...
# Processing Q2246283...
# Processing Q6635753...
# Processing Q866442...
# Processing Q65092...
# Processing Q3186688...
# Processing Q7653378...
# Processing Q735602...
# Processing Q4117639...
# Processing Q836244...
# Processing Q6959449...
# Processing Q20180599...
# Processing Q76683...
# Processing Q7291964...
# Processing Q749598...
# Processing Q3269478...
# Processing Q16001647...
# Processing Q5421105...
# Processing Q17092959...
# Processing Q7880535...
# Processing Q7320416...
# Processing Q452412...
# Processing Q2075856...
# Processing Q899456...
# Processing Q1550329...
# Processing Q113033247...
# Processing Q215313...
# Processing Q1455602...
# Processing Q6823703...
# Processing Q4681030...
# Processing Q3570341...
# Processing Q1334417...
# Processing Q5357916...
# Processing Q6675857...
# Processing Q1370759...
# Processing Q7462601...
# Processing Q4346098...
# Processing Q927682...
# Processing Q2347488...
# Processing Q7442523...
# Processing Q1898912...
# Processing Q423066...
# Processing Q3212744...
# Processing Q1806547...
# Processing Q2376736...
# Processing Q5051577...
# Processing Q7624780...
# Processing Q2914432...
#
# --- Processing Complete ---
# Total Processed: 4730
# Successful Records: 4729
# Failed Records: 1
# ---------------------------

# %%
def load_records(path):
    records = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            records.append(json.loads(line))
    return records

records = load_records("entity_data.jsonl")

# %%
def has_valid_instance_of(record):
    if record.get("status") != "success":
        return False

    attrs = record.get("attributes", {})
    instance_of = attrs.get("instance of")

    return isinstance(instance_of, str) and instance_of.strip() != ""

cleaned_records = [r for r in records if has_valid_instance_of(r)]

# %%
print(f"Total records: {len(records)}")
print(f"After dropping missing 'instance of': {len(cleaned_records)}")
# Out:
# Total records: 4730
# After dropping missing 'instance of': 2781

# %%
def write_jsonl(records, path):
    with open(path, "w", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

write_jsonl(cleaned_records, "has_instance_of.jsonl")

# %% [markdown]
# Create ground truth labels

# %%
def extract_instance_of_values(records):
    instance_values = set()

    for rec in records:
        attrs = rec.get("attributes", {})
        inst = attrs.get("instance of")
        if isinstance(inst, str) and inst.strip():
            instance_values.add(inst.lower())

    return sorted(instance_values)

instance_of_terms = extract_instance_of_values(cleaned_records)
print(len(instance_of_terms))
instance_of_terms
# Out:
# 757
# ['absorption refrigerator',
#  'absorption spectroscopy',
#  'abstract data type',
#  'academic conference',
#  'academic conference series',
#  'academic discipline',
#  'academic dispute',
#  'academic journal',
#  'academic journal article',
#  'academic major',
#  'acronym',
#  'act of congress in the united states',
#  'advisory board',
#  'aerodynamics',
#  'air sports',
#  'aircraft',
#  'aircraft class',
#  'aircraft lift class',
#  'aircraft lift-power class',
#  'aircraft model',
#  'aircraft power class',
#  'algebra over a field',
#  'algorithm',
#  'allotropy',
#  'altitude',
#  'ambiguous image',
#  'ammunition model',
#  'analytical chemical technique',
#  'animated short film',
#  'animation technique',
#  'annual event',
#  'anomaly',
#  'ansatz',
#  'appliance',
#  'archaeological artefact',
#  'archaeological sub-discipline',
#  'architectural structure',
#  'area of mathematics',
#  'article',
#  'artificial physical object',
#  'artificial satellite',
#  'aspect in a geographic region',
#  'aspect of history',
#  'aspect of sound',
#  'astrological concept',
#  'astronomical instrument',
#  'astronomical object type',
#  'astronomical observatory',
#  'astronomical phenomenon',
#  'astronomical survey',
#  'astrophysical process',
#  'atmosphere',
#  'atmospheric electricity',
#  'atmospheric layer',
#  'atmospheric optical phenomenon',
#  'atmospheric phenomenon',
#  'atom model',
#  'atomic clock',
#  'atomic pile',
#  'auditory illusion',
#  'award',
#  'bell test experiments',
#  'beta minus decay',
#  'bibliographic database',
#  'biochemistry method',
#  'biological process',
#  'biological rule',
#  'black-body radiation',
#  'blackboard',
#  'blanket term',
#  'book series',
#  'branch of astronomy',
#  'branch of biology',
#  'branch of chemistry',
#  'branch of engineering',
#  'branch of philosophy',
#  'branch of physics',
#  'branch of pseudoscience',
#  'branch of psychology',
#  'branch of science',
#  'business',
#  'camera parts, features and technologies',
#  'canonical ensemble',
#  'cat',
#  'catholic university',
#  'cause of accident',
#  'cause of death',
#  'celestial mechanics',
#  "certain aspects of a person's life",
#  'chemical anti-element',
#  'chemical classification',
#  'chemical element',
#  'chemical formalism',
#  'chemical law',
#  'chemical process',
#  'chemical property',
#  'chemical substance',
#  'cherenkov detector',
#  'chronology',
#  'class of chemical entities with similar applications or functions',
#  'class of chemical substances by use',
#  'class of parts',
#  'classical element',
#  'classification scheme',
#  'clifford gate',
#  'coachwork type',
#  'coefficient',
#  'color in nature',
#  'color of noise',
#  'committee',
#  'company',
#  'comparison',
#  'comparison of chernobyl and other radioactivity releases',
#  'compressible flow',
#  'computation',
#  'computational approach',
#  'computational hardness assumption',
#  'concept',
#  'concept in physics',
#  'conception',
#  'conceptual model',
#  'condition',
#  'conservation law',
#  'continuum',
#  'contour line',
#  'control system',
#  'controversial invention',
#  'convection',
#  'coordinates transformation',
#  'correspondence',
#  'cosmic-ray observatory',
#  'cosmological epoch',
#  'cosmological horizon',
#  'cosmological model',
#  'cosmological principles',
#  'cosmology',
#  'coupling constant',
#  'craft',
#  'crystal structure',
#  'crystal system',
#  'cultural depiction',
#  'cutting fluid',
#  'dagger',
#  'database table',
#  'debate',
#  'decay mode',
#  'delay',
#  'derivative',
#  'design',
#  'device feature',
#  'diagram',
#  'difference',
#  'differential equation',
#  'digital camera',
#  'dimensionless unit',
#  'directed-energy weapon',
#  'disciplinary repository',
#  'discovery',
#  'distortion in electrical engineering',
#  'double-slit experiment',
#  'duality',
#  'dwarf irregular galaxy',
#  'dynamical picture',
#  'early life',
#  'earthquake',
#  'education theory',
#  'effect',
#  'effects of nuclear explosions',
#  'electric bell',
#  'electric current',
#  'electric process',
#  'electrical circuit',
#  'electrical element',
#  'electrical phenomenon',
#  'electromagnetic radiation',
#  'electromagnetic wave',
#  'electronic device',
#  'electrostatic generator',
#  'electrostatic particle accelerator',
#  'elementary particle',
#  'elliptic differential equation',
#  'empirical relationship',
#  'energy',
#  'energy level',
#  'energy production',
#  'energy source',
#  'engine class',
#  'environmental effects',
#  'environmental issue',
#  'epoch',
#  'equation',
#  'equipotential surface',
#  'era',
#  'ethnological term',
#  'euclidean vector',
#  'evolution by phenotype',
#  'exact solutions in general relativity',
#  'exotic atom',
#  'experiment',
#  'explosive device',
#  'extraterrestrial vortex',
#  'extreme weather',
#  'eyewear',
#  'facility',
#  'family',
#  'family of distributions',
#  'fast-neutron reactor',
#  'fiber',
#  'fictional chemical element',
#  'fictional technology',
#  'fictitious force',
#  'field of study',
#  'film',
#  'fine-tuning',
#  'fire',
#  'fixed construction',
#  'flow type',
#  'fluorescence microscope',
#  'flux',
#  'food preservation',
#  'force',
#  'form of energy',
#  'formula',
#  'frame of reference',
#  'frequency',
#  'fringe theory',
#  'function',
#  'fundamental interaction',
#  'fundamental state of matter',
#  'fusion power',
#  'fusion reactor',
#  'futuristic concept',
#  'g-type main-sequence star',
#  'galaxy',
#  'galaxy filament',
#  'galaxy wall',
#  'gamma-ray telescope',
#  'gas law',
#  'gauge fixing',
#  'general quantity',
#  'general term',
#  'generator',
#  'genre',
#  'geographic envelope',
#  'geomagnetic storm',
#  'geometric concept',
#  'geometry',
#  'glass',
#  'gold mine',
#  'government agency',
#  'gravitational wave event',
#  'gravitational-wave detector',
#  'great circle',
#  'group',
#  'group of humans',
#  'group of women',
#  'group or class of chemical entities',
#  'group or class of chemical substances',
#  'hadron collider',
#  'halo',
#  'heat engine',
#  'heat flow rate',
#  'high flux reactor',
#  'human',
#  'human impact on the environment',
#  'hydrogen line spectrum',
#  'hyperbolic partial differential equation',
#  'hypernova',
#  'hypersurface',
#  'hypothesis',
#  'hypothetical astronomical object',
#  'hypothetical entity',
#  'hypothetical particle',
#  'hypothetical scientific object',
#  'hypothetical star',
#  'hypothetical technology',
#  'ieee radio band',
#  'image',
#  'incident',
#  'increase',
#  'index number',
#  'industry',
#  'inequation',
#  'inscription',
#  'institute',
#  'integral transform',
#  'interdisciplinary science',
#  'interface standard',
#  'international organization',
#  'international standard',
#  'invariant',
#  'invention',
#  'ionizing radiation',
#  'iso standard',
#  'isotope of helium',
#  'isotope of hydrogen',
#  'isotope of neutronium',
#  'isotope of plutonium',
#  'itu radio band',
#  'joining technology',
#  'kind of quantity',
#  'lab technique',
#  'laboratory',
#  'laboratory equipment',
#  'large quasar group',
#  'large-scale structure of the universe',
#  'laser diode',
#  'latin phrase',
#  'law of thermodynamics',
#  'learned society',
#  'lecture',
#  'legendre function',
#  'lens type',
#  'lenticular galaxy',
#  'level of measurement',
#  'limit',
#  'limited company',
#  'linear combination',
#  'literary work',
#  'logarithmic unit',
#  'logical contradiction',
#  'long-term experiment',
#  'longitudinal wave',
#  'machine',
#  'macroscopic quantum phenomena',
#  'magic trick',
#  'magnetic anomaly',
#  'magnetic ordering',
#  'magnetosphere',
#  'magnitude',
#  'manufacturing process',
#  'many-body theory',
#  'marine propulsion',
#  'material',
#  'material defect',
#  'material flow',
#  'material property',
#  'mathematical concept',
#  'mathematical constant',
#  'mathematical descriptions of the electromagnetic field',
#  'mathematical expression',
#  'mathematical model',
#  'mathematical notation',
#  'mathematical object',
#  'mathematical problem',
#  'mathematical term',
#  'mathematical theory',
#  'maximum temperature',
#  'measurand',
#  'measure',
#  'measurement',
#  'measuring instrument',
#  'mechanical paradox',
#  'mechanical properties of fiber',
#  'mechanical property',
#  'mechanism',
#  'medical imaging',
#  'medical procedure type',
#  'medical test',
#  'medical test type',
#  'metaphor',
#  'meteorological index',
#  'meteorological phenomenon',
#  'meteorology',
#  'method',
#  'metric',
#  'metric function',
#  'michelson interferometer',
#  'military project',
#  'military training area',
#  'minimum temperature',
#  'mirage',
#  'mirror',
#  'mirror image',
#  'missile model',
#  'mixture',
#  'mnemonic',
#  'model',
#  'model of computation',
#  'modeling assumption',
#  'modulus',
#  'molten salt reactor',
#  'motion',
#  'motions of the earth',
#  'multiple',
#  'multiple unit',
#  'museum',
#  'musical concept',
#  'musical instrument',
#  'naming controversy',
#  'narrative technique',
#  'nasa facility',
#  'natural nuclear fission reactor',
#  'natural phenomenon',
#  'natural resource',
#  'nautical language',
#  'network',
#  'neutrino detector',
#  'no-go theorem',
#  'noise',
#  'non-classical state of matter',
#  'non-existent substance',
#  'non-periodic comet',
#  'nonprofit organization',
#  'notation',
#  'nuclear chain reaction',
#  'nuclear explosion',
#  'nuclear facility',
#  'nuclear fuel',
#  'nuclear isomer',
#  'nuclear physics term',
#  'nuclear power plant',
#  'nuclear program',
#  'nuclear reaction',
#  'nuclear reactor',
#  'nuclear technology',
#  'numerical algorithm',
#  'numerical method in differential equations',
#  'numerical method in hyperbolic partial differential equations',
#  'numerical methods in continuum mechanics',
#  'objective quality metric',
#  'observable universe',
#  'obsolete unit of measurement',
#  'occurrence',
#  'online database',
#  'open problem',
#  'open-access journal',
#  'optic method',
#  'optical aberration',
#  'optical illusion',
#  'optical instrument',
#  'optical phenomenon',
#  'optical property',
#  'optical toy',
#  'orbit',
#  'ordinary differential equation',
#  'organization',
#  'oscillation',
#  'outflow channel',
#  'packing density',
#  'parabolic partial differential equation',
#  'paradox',
#  'parameter',
#  'parametrization',
#  'paranormal',
#  'particle accelerator',
#  'particle detector',
#  'particle physics',
#  'particle physics experiment',
#  'particle radiation',
#  'party',
#  'pattern',
#  'peaceful nuclear explosion',
#  'periodic table form',
#  'phase',
#  'phase (matter)',
#  'phase change',
#  'phenomenon',
#  'philosophical concept',
#  'philosophical problem',
#  'philosophical theory',
#  'photographic technique',
#  'physical concept',
#  'physical constant',
#  'physical container',
#  'physical law',
#  'physical model',
#  'physical paradox',
#  'physical phenomenon',
#  'physical process',
#  'physical property',
#  'physical quantity',
#  'physical theory',
#  'physicochemical process',
#  'physics award',
#  'physics equation',
#  'physics experiment',
#  'physics term',
#  'planetary magnetic field',
#  'planform',
#  'plot',
#  'polarization',
#  'polynomial sequence',
#  'polyphyly',
#  'postulate',
#  'postulates of special relativity',
#  'potential',
#  'principle',
#  'privately held company',
#  'probability distribution',
#  'probability measure',
#  'problem',
#  'procedural texture',
#  'process',
#  'process function',
#  'product category',
#  'production environment factor',
#  'profession',
#  'progressive wave',
#  'project',
#  'pronunciation',
#  'property',
#  'proposition',
#  'pseudoscience',
#  'public research university',
#  'publication identifier',
#  'pulsar',
#  'q17444909',
#  'q3342045',
#  'q62078547',
#  'q778869',
#  'quality',
#  'quantum algorithm',
#  'quantum effect',
#  'quantum number',
#  'quasar',
#  'quasiparticle',
#  'radio frequency range',
#  'radio interferometer',
#  'radioactive waste repository',
#  'radioisotope thermoelectric generator',
#  'radiometric dating',
#  'rainbow',
#  'randomized algorithm',
#  'ratio',
#  'reference atmospheric model',
#  'reference point',
#  'reference work',
#  'refraction',
#  'region of space',
#  'relation',
#  'relativistic wave equation',
#  'religious views by individual',
#  'renewable resource',
#  'representation',
#  'research center',
#  'research collaboration',
#  'research institute',
#  'research organization',
#  'research program',
#  'research reactor',
#  'research satellite',
#  'research site',
#  'riddle',
#  'right-hand rule',
#  'role',
#  'rule',
#  'running characteristics',
#  'scalar quantity',
#  'science award',
#  'science project',
#  'scientific controversy',
#  'scientific hypothesis',
#  'scientific instrument',
#  'scientific journal',
#  'scientific knowledge',
#  'scientific law',
#  'scientific method',
#  'scientific model',
#  'scientific society',
#  'scientific technique',
#  'scientific theory',
#  'sea state',
#  'search algorithm',
#  'second-order class',
#  'sensor',
#  'serial',
#  'set',
#  'shape',
#  'shell of an astronomical object',
#  'si base unit',
#  'si derived unit',
#  'si unit with special name',
#  'sibling duo',
#  'signal',
#  'sky phenomenon',
#  'social movement',
#  'social phenomenon',
#  'software',
#  'solar electric propulsion',
#  'solar phenomena',
#  'solar proton event',
#  'solid-state physics',
#  'sound',
#  'sound concept',
#  'source type',
#  'space mission',
#  'space probe',
#  'space telescope',
#  'spacecraft',
#  'spacecraft series',
#  'special function',
#  'special orthogonal group',
#  'spectral class',
#  'spectral color',
#  'spectral line',
#  'spectral series',
#  'spectrum',
#  'speed',
#  'stable isotope',
#  'standards organization',
#  'standing wave',
#  'star',
#  'state function',
#  'state of matter',
#  'steam engine',
#  'stellar wind',
#  'stellar-wind bubble',
#  'stellarator',
#  'stochastic differential equation',
#  'storage ring',
#  'structural class of chemical entities',
#  'structure',
#  'subjective quality',
#  'submarine type',
#  'superfluidity',
#  'superhydrophobe',
#  'supernova',
#  'superpower',
#  'superseded scientific theory',
#  'surface',
#  'surveillance',
#  'suspension bridge',
#  'symmetry',
#  'synchrotron',
#  'syndrome',
#  'system of units',
#  'task',
#  'technical limitation',
#  'technical standard',
#  'technical term',
#  'technique',
#  'technology',
#  'television series',
#  'temperature',
#  'temperature scale',
#  'temporal entity',
#  'tendency',
#  'tensor field',
#  'term',
#  'textbook',
#  'theorem',
#  'theoretical astronomy',
#  'theory',
#  'thermal property',
#  'thermodynamic material property',
#  'thermodynamic process',
#  'thermodynamic temperature',
#  'thought experiment',
#  'tidal bore',
#  'tidal force',
#  'time interval',
#  'timeline',
#  'timepiece',
#  'tokamak',
#  'toy',
#  'trademark',
#  'train and rail category',
#  'trajectory',
#  'transformation',
#  'transformer',
#  'transport phenomenon',
#  'triad',
#  'type of chemical entity',
#  'type of cyclone',
#  'type of electronic component',
#  'type of equilibrium',
#  'type of interaction',
#  'type of machine element',
#  'type of magnets',
#  'type of mathematical function',
#  'type of meteorological phenomenon',
#  'type of mixture of chemical entities',
#  'type of musical instrument',
#  'type of number',
#  'type of object',
#  'type of physical object by use',
#  'type of pollution',
#  'type of polymer',
#  'type of process',
#  'type of property',
#  'type of quantum particle',
#  'type of relation',
#  'type of sport',
#  'type of statistic',
#  'type of system',
#  'type of technology',
#  'type of warning system',
#  'ucum derived unit',
#  'ultra-high-energy cosmic ray',
#  'ultralight material',
#  'underground research laboratory',
#  'unit of acceleration',
#  'unit of activity referred to a radionuclide',
#  'unit of angular velocity',
#  'unit of area',
#  'unit of dose equivalent',
#  'unit of dynamic viscosity',
#  'unit of electric charge',
#  'unit of energy',
#  'unit of exposure',
#  'unit of force',
#  'unit of frequency',
#  'unit of information',
#  'unit of length',
#  'unit of luminance',
#  'unit of magnetic flux density',
#  'unit of mass',
#  'unit of measurement',
#  'unit of molar energy',
#  'unit of power',
#  'unit of pressure',
#  'unit of spectral irradiance with respect to wavelength',
#  'unit of speed',
#  'unit of time',
#  'unit of torque',
#  'unit of volume',
#  'united states national laboratory',
#  'universal law',
#  'universe',
#  'university',
#  'urban legend',
#  'use',
#  'vector operator',
#  'vehicle axis',
#  'video game term',
#  'void',
#  'volume ratio',
#  'vortex ring',
#  'water treatment',
#  'wave',
#  'wave function',
#  'weapon model',
#  'weapon type',
#  'weather',
#  'webcomic',
#  'welding process',
#  'wikibase reason for deprecated rank',
#  'wikimedia article covering multiple topics',
#  'wikimedia article covering two opposite properties or topics',
#  'wikimedia disambiguation page',
#  'wikimedia glossary list article',
#  'wikimedia information list',
#  'wikimedia introduction to topic',
#  'wikimedia list article',
#  'wikimedia outline article',
#  'wikimedia set index article',
#  'wikimedia timeline',
#  'wikipedia orders of magnitude list',
#  'wind speed',
#  'wing configuration',
#  'work',
#  'work of science',
#  'working group',
#  'world view',
#  'written work',
#  'zone']

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
mapping = pd.read_csv("subclasses.csv")

# dictionary: instance_of -> subfield
instance_to_label = dict(
    zip(mapping["instance_of"], mapping["subclass"])
)

# %%
articles = []
with open("has_instance_of.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        articles.append(json.loads(line))

len(articles)
# Out:
# 2781

# %%
def build_text(entry):
    parts = []

    if entry.get("description"):
        parts.append(entry["description"])

    attrs = entry.get("attributes", {})

    for key in ["part of", "subclass of", "facet of", "has characteristic"]:
        if key in attrs:
            parts.append(str(attrs[key]))

    return " ".join(parts)

# %%
texts = []
labels = []

for entry in articles:
    attrs = entry.get("attributes", {})
    inst = attrs.get("instance of")

    if inst in instance_to_label:
        label = instance_to_label[inst]
        text = build_text(entry)

        # filter empty text
        if text.strip():
            texts.append(text)
            labels.append(label)

from collections import Counter
print(Counter(labels))
# Out:
# Counter({'Other': 1022, 'Physicist': 746, 'Mathematical Concept': 230, 'Technology': 117, 'Particle physics': 96, 'Classical mechanics': 87, 'Thermodynamics': 64, 'Astronomy and Planetary': 62, 'Nuclear and atomic physics': 46, 'Condensed matter': 40, 'Relativity': 34, 'Optics': 33, 'Atomic, molecular, and optical physics': 23, 'Quantum physics': 19})

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(
    texts,
    labels,
    test_size=0.2,
    random_state=42,
    stratify=labels
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    lowercase=True,
    stop_words="english",
    ngram_range=(1, 2),
    min_df=3
)

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB(alpha=0.5)
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB(alpha=0.5)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

predicted = model.predict(X_test_vec)

print(np.mean(predicted == y_test))
# Out:
# 0.7309160305343512

# %%
features = len(vectorizer.get_feature_names_out())
print("Number of features:", features)

#Sparsity is the number of zero-valued elements divided by the total number of elements
sparsity = (1- X_train_vec.count_nonzero() / np.prod(X_train_vec.shape)) * 100
print("Sparsity:", sparsity)
# Out:
# Number of features: 1358
# Sparsity: 99.60562528778458

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
cm = confusion_matrix(y_test, predicted, labels=model.classes_)

sns.heatmap(cm, xticklabels=model.classes_,
            yticklabels=model.classes_,
            annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(rotation=45, ha="right", fontsize = 8)  # rotate x labels
plt.yticks( fontsize = 8)            
plt.title("Confusion Matrix for Predicted Subclasses")
plt.show()

# %%
from sklearn.metrics import f1_score

y_pred = model.predict(X_test_vec)
f1 = f1_score(y_test, y_pred, average="weighted")
f1
# Out:
# 0.6735025165626167

# %% [markdown]
# Creating New Dataset with predicted subclasses and relavent fields from the original jsonl

# %%
records = []

with open("has_instance_of.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)

        attrs = obj.get("attributes", {})

        record = {
            "QID": obj.get("QID"),
            "label": obj.get("label"),
            "description": obj.get("description"),

            # attributes (may be missing)
            "instance_of": attrs.get("instance of"),
            "part_of": attrs.get("part of"),
            "subclass_of": attrs.get("subclass of"),
            "facet_of": attrs.get("facet of"),
            "has_characteristic": attrs.get("has characteristic"),
        }

        records.append(record)

df = pd.DataFrame(records)
df
# Out:
#            QID                                       label  \
# 0      Q208138                                Faraday cage
# 1       Q33198                               string theory
# 2     Q2027476                            Anatoli Bugorski
# 3      Q177045                second law of thermodynamics
# 4     Q2164598                          Wardenclyffe Tower
# ...        ...                                         ...
# 2776  Q7442523                             Sebastian Seung
# 2777  Q1898912                                 Mario Livio
# 2778  Q3212744  La Science et l'Hypothèse / Henri Poincaré
# 2779  Q2376736                   history of thermodynamics
# 2780  Q7624780                              strontium unit
#
#                                             description  \
# 0     enclosure of conductive mesh used to block ele...
# 1     physical theory of quantized one-dimensional o...
# 2     Russian scientist involved in an accident with...
# 3     law of physics stating that systems spontaneou...
# 4     early experimental wireless transmission stati...
# ...                                                 ...
# 2776                                 American physicist
# 2777  Romanian-born Israeli–American astrophysicist ...
# 2778        work by French mathematician Henri Poincaré
# 2779                                  aspect of history
# 2780  unit used to measure the amount of radioactivi...
#
#                 instance_of         part_of          subclass_of facet_of  \
# 0                experiment            None   physical container     None
# 1         branch of physics            None  theoretical physics     None
# 2                     human            None                 None     None
# 3     law of thermodynamics  thermodynamics                 None     None
# 4                laboratory            None                 None     None
# ...                     ...             ...                  ...      ...
# 2776                  human            None                 None     None
# 2777                  human            None                 None     None
# 2778           written work            None                 None     None
# 2779      aspect of history            None                 None     None
# 2780    unit of measurement            None                 None     None
#
#      has_characteristic
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ...                 ...
# 2776               None
# 2777               None
# 2778               None
# 2779               None
# 2780               None
#
# [2781 rows x 8 columns]

# %%
def build_text(row):
    fields = [
        row["description"],
        row["instance_of"],
        row["part_of"],
        row["subclass_of"],
        row["facet_of"],
        row["has_characteristic"],
    ]
    return " ".join([str(f) for f in fields if pd.notnull(f)])

df["model_text"] = df.apply(build_text, axis=1)
df
# Out:
#            QID                                       label  \
# 0      Q208138                                Faraday cage
# 1       Q33198                               string theory
# 2     Q2027476                            Anatoli Bugorski
# 3      Q177045                second law of thermodynamics
# 4     Q2164598                          Wardenclyffe Tower
# ...        ...                                         ...
# 2776  Q7442523                             Sebastian Seung
# 2777  Q1898912                                 Mario Livio
# 2778  Q3212744  La Science et l'Hypothèse / Henri Poincaré
# 2779  Q2376736                   history of thermodynamics
# 2780  Q7624780                              strontium unit
#
#                                             description  \
# 0     enclosure of conductive mesh used to block ele...
# 1     physical theory of quantized one-dimensional o...
# 2     Russian scientist involved in an accident with...
# 3     law of physics stating that systems spontaneou...
# 4     early experimental wireless transmission stati...
# ...                                                 ...
# 2776                                 American physicist
# 2777  Romanian-born Israeli–American astrophysicist ...
# 2778        work by French mathematician Henri Poincaré
# 2779                                  aspect of history
# 2780  unit used to measure the amount of radioactivi...
#
#                 instance_of         part_of          subclass_of facet_of  \
# 0                experiment            None   physical container     None
# 1         branch of physics            None  theoretical physics     None
# 2                     human            None                 None     None
# 3     law of thermodynamics  thermodynamics                 None     None
# 4                laboratory            None                 None     None
# ...                     ...             ...                  ...      ...
# 2776                  human            None                 None     None
# 2777                  human            None                 None     None
# 2778           written work            None                 None     None
# 2779      aspect of history            None                 None     None
# 2780    unit of measurement            None                 None     None
#
#      has_characteristic                                         model_text
# 0                  None  enclosure of conductive mesh used to block ele...
# 1                  None  physical theory of quantized one-dimensional o...
# 2                  None  Russian scientist involved in an accident with...
# 3                  None  law of physics stating that systems spontaneou...
# 4                  None  early experimental wireless transmission stati...
# ...                 ...                                                ...
# 2776               None                           American physicist human
# 2777               None  Romanian-born Israeli–American astrophysicist ...
# 2778               None  work by French mathematician Henri Poincaré wr...
# 2779               None                aspect of history aspect of history
# 2780               None  unit used to measure the amount of radioactivi...
#
# [2781 rows x 9 columns]

# %%
X_all = vectorizer.transform(df["model_text"])

df["predicted_subclass"] = model.predict(X_all)
df
# Out:
#            QID                                       label  \
# 0      Q208138                                Faraday cage
# 1       Q33198                               string theory
# 2     Q2027476                            Anatoli Bugorski
# 3      Q177045                second law of thermodynamics
# 4     Q2164598                          Wardenclyffe Tower
# ...        ...                                         ...
# 2776  Q7442523                             Sebastian Seung
# 2777  Q1898912                                 Mario Livio
# 2778  Q3212744  La Science et l'Hypothèse / Henri Poincaré
# 2779  Q2376736                   history of thermodynamics
# 2780  Q7624780                              strontium unit
#
#                                             description  \
# 0     enclosure of conductive mesh used to block ele...
# 1     physical theory of quantized one-dimensional o...
# 2     Russian scientist involved in an accident with...
# 3     law of physics stating that systems spontaneou...
# 4     early experimental wireless transmission stati...
# ...                                                 ...
# 2776                                 American physicist
# 2777  Romanian-born Israeli–American astrophysicist ...
# 2778        work by French mathematician Henri Poincaré
# 2779                                  aspect of history
# 2780  unit used to measure the amount of radioactivi...
#
#                 instance_of         part_of          subclass_of facet_of  \
# 0                experiment            None   physical container     None
# 1         branch of physics            None  theoretical physics     None
# 2                     human            None                 None     None
# 3     law of thermodynamics  thermodynamics                 None     None
# 4                laboratory            None                 None     None
# ...                     ...             ...                  ...      ...
# 2776                  human            None                 None     None
# 2777                  human            None                 None     None
# 2778           written work            None                 None     None
# 2779      aspect of history            None                 None     None
# 2780    unit of measurement            None                 None     None
#
#      has_characteristic                                         model_text  \
# 0                  None  enclosure of conductive mesh used to block ele...
# 1                  None  physical theory of quantized one-dimensional o...
# 2                  None  Russian scientist involved in an accident with...
# 3                  None  law of physics stating that systems spontaneou...
# 4                  None  early experimental wireless transmission stati...
# ...                 ...                                                ...
# 2776               None                           American physicist human
# 2777               None  Romanian-born Israeli–American astrophysicist ...
# 2778               None  work by French mathematician Henri Poincaré wr...
# 2779               None                aspect of history aspect of history
# 2780               None  unit used to measure the amount of radioactivi...
#
#         predicted_subclass
# 0                    Other
# 1                    Other
# 2                Physicist
# 3                    Other
# 4                    Other
# ...                    ...
# 2776             Physicist
# 2777             Physicist
# 2778             Physicist
# 2779                 Other
# 2780  Mathematical Concept
#
# [2781 rows x 10 columns]

# %%
gt_map = pd.read_csv("subclasses.csv")
#gt_map.head()

df = df.merge(
    gt_map,
    on="instance_of",
    how="left"
)

# %%
df = df.rename(columns={"subclass": "ground_truth_subclass"})
df
# Out:
#            QID                                       label  \
# 0      Q208138                                Faraday cage
# 1       Q33198                               string theory
# 2     Q2027476                            Anatoli Bugorski
# 3      Q177045                second law of thermodynamics
# 4     Q2164598                          Wardenclyffe Tower
# ...        ...                                         ...
# 2777  Q7442523                             Sebastian Seung
# 2778  Q1898912                                 Mario Livio
# 2779  Q3212744  La Science et l'Hypothèse / Henri Poincaré
# 2780  Q2376736                   history of thermodynamics
# 2781  Q7624780                              strontium unit
#
#                                             description  \
# 0     enclosure of conductive mesh used to block ele...
# 1     physical theory of quantized one-dimensional o...
# 2     Russian scientist involved in an accident with...
# 3     law of physics stating that systems spontaneou...
# 4     early experimental wireless transmission stati...
# ...                                                 ...
# 2777                                 American physicist
# 2778  Romanian-born Israeli–American astrophysicist ...
# 2779        work by French mathematician Henri Poincaré
# 2780                                  aspect of history
# 2781  unit used to measure the amount of radioactivi...
#
#                 instance_of         part_of          subclass_of facet_of  \
# 0                experiment            None   physical container     None
# 1         branch of physics            None  theoretical physics     None
# 2                     human            None                 None     None
# 3     law of thermodynamics  thermodynamics                 None     None
# 4                laboratory            None                 None     None
# ...                     ...             ...                  ...      ...
# 2777                  human            None                 None     None
# 2778                  human            None                 None     None
# 2779           written work            None                 None     None
# 2780      aspect of history            None                 None     None
# 2781    unit of measurement            None                 None     None
#
#      has_characteristic                                         model_text  \
# 0                  None  enclosure of conductive mesh used to block ele...
# 1                  None  physical theory of quantized one-dimensional o...
# 2                  None  Russian scientist involved in an accident with...
# 3                  None  law of physics stating that systems spontaneou...
# 4                  None  early experimental wireless transmission stati...
# ...                 ...                                                ...
# 2777               None                           American physicist human
# 2778               None  Romanian-born Israeli–American astrophysicist ...
# 2779               None  work by French mathematician Henri Poincaré wr...
# 2780               None                aspect of history aspect of history
# 2781               None  unit used to measure the amount of radioactivi...
#
#         predicted_subclass ground_truth_subclass
# 0                    Other                 Other
# 1                    Other                 Other
# 2                Physicist             Physicist
# 3                    Other        Thermodynamics
# 4                    Other                 Other
# ...                    ...                   ...
# 2777             Physicist             Physicist
# 2778             Physicist             Physicist
# 2779             Physicist                 Other
# 2780                 Other                 Other
# 2781  Mathematical Concept  Mathematical Concept
#
# [2782 rows x 11 columns]

# %%
final_cols = [
    "QID",
    "label",
    "description",
    "instance_of",
    "part_of",
    "subclass_of",
    "facet_of",
    "has_characteristic",
    "predicted_subclass",
    "ground_truth_subclass"
]

final_df = df[final_cols]

final_df.to_csv("articles_with_predictions.csv", index=False)
